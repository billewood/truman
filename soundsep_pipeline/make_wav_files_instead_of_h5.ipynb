# %% [markdown]
# ## Based on the code which :
# ## Iterates through a soundsep csv, opens wav files, saves biosound H5 files for further analysis.
# # But instead it just makes short wav files for use in a GAN.

# %%
# from scipy import integrate, optimize

import soundfile as sf
import numpy as np
from scipy.signal import spectrogram, butter, sosfilt, sosfiltfilt, correlate
from scipy.io.wavfile import read, write
import IPython.display as ipd
# import sys
from collections import Counter
import os
import pandas as pd
# import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
import pickle
import csv
from soundsig.sound import BioSound 
from soundsig.sound import WavFile


# from ipywidgets import interact, fixed
# from ipywidgets import widgets
import matplotlib.pyplot as plt

def plot_a_spectrogram(w, fs:int=48000, title:str=spectrogram, nfft:int=2048):
    ff, tt, Sxx = spectrogram(w, fs=fs, nfft=nfft)
    max_ff = 10000 # only plot the first 10kHz
    ff_index = np.where(ff < max_ff)
    ff = ff[ff_index]
    Sxx = Sxx[ff_index]

    plt.figure(figsize=(10, 5))
    plt.pcolormesh(tt, ff[:max_ff], Sxx[:max_ff], cmap='plasma', shading='auto')
    # plt.pcolormesh(tt, ff[:145], Sxx[:145], cmap='plasma', shading='gouraud')
    plt.title(title)
    plt.xlabel('t (sec)')
    plt.ylabel('Frequency (Hz)')
    plt.grid()

# %%
base_folder = '/Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/'
#'/Users/williamwood/Documents/Sound_Localization/for_soundsep/2023 maeve and jaewon/14_38_03_18_07_2023-data'
#'/Users/williamwood/Documents/Sound_Localization/for_soundsep/maeves data'#'/Users/williamwood/Documents/Sound_Localization/for_soundsep/14-38-03_18-07-2023' #7_18_23__09_29_44'
wave_files_folder = base_folder
#'/Users/williamwood/Documents/Sound_Localization/for_soundsep/14-38-03_18-07-2023'
# wave_files_folder = '/Users/williamwood/Documents/Sound_Localization/for_soundsep/7_18_23__09_29_44'
# Sound_Localization/for_soundsep/7_18_23__09_29_44'

file_name = os.path.join(base_folder,'_appdata','save','segments.csv')

print(file_name)
df = pd.read_csv(file_name, sep=',',header=0)        
print(f'Length of dataframe: {len(df)}')
print(f'Column names: {df.columns}')
print(f'Tags: {df["Tags"].unique()}')
# Out:
# /Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/_appdata/save/segments.csv
# Length of dataframe: 4344
# Column names: Index(['SourceName', 'SourceChannel', 'StartIndex', 'StopIndex', 'Tags',
#        'Coords'],
#       dtype='object')
# Tags: ['["1"]' '["6"]' '["2"]' '["5"]' '["0"]' '["4"]' '["3"]' '[]']

# %%
os.chdir(base_folder)

# This will be the output directory
if not os.path.exists('wavs'):
    os.makedirs('wavs')

# %%
# Read the csv file as a pandas data frame
soundsepPD = df
nsounds = len(soundsepPD)
print(nsounds)
wav_names = {
    'BroGre1354M':'audio_423212900Hz_14-38-03_18-07-2023.wav',
    'WhiWhi6607F':'audio_432736310Hz_14-38-04_18-07-2023.wav',
    'BluGre1214F':'audio_442360000Hz_14-38-00_18-07-2023.wav',
    'WhiWhi1541M':'audio_458185540Hz_14-37-58_18-07-2023.wav'
}
plotMe=True
normalize = True

# check the wav files to see if they have the same sampling rate
srs = list()
for file in wav_names.values():
    filename = os.path.join(wave_files_folder, file)
    track = sf.SoundFile(filename)
    srs.append(track.samplerate)
    print(f'{filename} has a sample rate of {track.samplerate}')
    track.close()
fs = srs[0]
# Out:
# 4344
# /Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/audio_423212900Hz_14-38-03_18-07-2023.wav has a sample rate of 48000
# /Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/audio_432736310Hz_14-38-04_18-07-2023.wav has a sample rate of 48000
# /Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/audio_442360000Hz_14-38-00_18-07-2023.wav has a sample rate of 48000
# /Users/williamwood/Documents/Data/Field Station Recordings/for_soundsep/14_38_03_18_07_2023/audio_458185540Hz_14-37-58_18-07-2023.wav has a sample rate of 48000

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0   SourceName  SourceChannel  StartIndex  \
# 0                0           0  BroGre1354M              0      705034
# 1                1           1  BluGre1214F              2      739121
# 2                2           2  BluGre1214F              2      773851
# 3                3           3  BluGre1214F              2      844891
# 4                4           4  BroGre1354M              0      910549
# ...            ...         ...          ...            ...         ...
# 4339          4339        4339  WhiWhi1541M              3   297302736
# 4340          4340        4340  BluGre1214F              2   297324812
# 4341          4341        4341  BluGre1214F              2   297367001
# 4342          4342        4342  BluGre1214F              2   298070022
# 4343          4343        4343  WhiWhi1541M              3   298089447
#
#       StopIndex   Tags                                             Coords
# 0        709502  ["1"]  [8.153053283691406, 11.92204475402832, 5.47700...
# 1        741816  ["6"]  [11.00963020324707, 12.903932571411133, 5.4287...
# 2        776369  ["2"]  [11.17556381225586, 11.674291610717773, 3.4400...
# 3        848558  ["6"]  [10.986668586730957, 12.001487731933594, 3.246...
# 4        913839  ["5"]  [9.732298851013184, 11.947017669677734, 0.9106...
# ...         ...    ...                                                ...
# 4339  297305283  ["5"]                                                NaN
# 4340  297329004  ["6"]                                                NaN
# 4341  297371644  ["6"]                                                NaN
# 4342  298074525  ["6"]                                                NaN
# 4343  298092579  ["5"]                                                NaN
#
# [4344 rows x 8 columns]

# %%
# def return_voc(df_index):
#     segment = df.iloc[df_index]
#     file_name = wav_names.get(segment['SourceName']) # get the filename from the bird name
#     # print(f'opening data file:{os.path.join(base_folder, wav_names.get(segment['SourceName'] ) ) }')
#     fs, data_wav = read(os.path.join(base_folder, wav_names.get(segment['SourceName'])))
#     chunk = data_wav[segment['StartIndex']:segment['StopIndex']]
#     return chunk


def read_audio_section(filename, start_frame, stop_frame):
    track = sf.SoundFile(filename)

    can_seek = track.seekable() # True
    if not can_seek:
        raise ValueError("Not compatible with seeking")

    sr = track.samplerate
    frames_to_read = stop_frame - start_frame
    track.seek(start_frame)
    audio_section = track.read(frames_to_read)
    track.close()
    return audio_section, sr

# %%
# check index below TODO!!!!!
for row_num in range(2):
    go = True
    print(f'row_num={row_num}, startindex={df.iloc[row_num]["StartIndex"]}, stopindex={df.iloc[row_num]["StopIndex"]}')
    dt = df.iloc[row_num]['StopIndex'] - df.iloc[row_num]['StartIndex']
 
    if dt<460: # if the syllable is less than 5ms, skip it 
        print(f'Syllable is too short (dt = {dt}), padding')
        # go = False
        # elif (dt < 460):
        ptadd = int((460 - dt)/2 + 1) # nwinlen requires a syllable of at least 460 samples to calculate biosound stuff, don't know why- Frederic had this at 250 before
        istart = df.iloc[row_num]['StartIndex']-ptadd
        if istart < 0 :
            print ('Skipping short syllable at very start of file')
            go = False
        iend = df.iloc[row_num]['StopIndex'] + ptadd
        # if (iend > len(soundIN.data) ):
        #     print ('Skipping short syllable at eend of file')
        #     go = False
    else:
        istart = df.iloc[row_num]['StartIndex']
        iend = df.iloc[row_num]['StopIndex']
    print(f'go={go} istart={istart} iend={iend} row_num={row_num}')
    # print(f'dt={dt}, syll_start= {int(istart/fs)}, syll_end={int(iend/fs)}')

    if go:
        # soundIN = WavFile(file_name=os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])))
        # soundSYL = soundIN.data[istart:iend]
        # load just the segment of the audio file that we want
        soundSyl, sr = read_audio_section(os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])), start_frame=istart, stop_frame=iend)
        
        birdname = df.iloc[row_num]['SourceName']
        if len(df.iloc[row_num]['Tags']) > 0:
            calltype = df.iloc[row_num]['Tags']
        else:
            calltype = 'unknown'
            
            
        # # Normalize if wanted- I don't want to
        # if normalize :
        #     maxAmp = np.abs(soundIN.data).max() 
        # else:
        #     maxAmp = 1.0
        
        # Create BioSound Object
        # myBioSound = BioSound(soundWave=soundSyl, fs=fs, emitter=birdname, calltype = calltype)
# Out:
# row_num=0, startindex=705034, stopindex=709502
# go=True istart=705034 iend=709502 row_num=0
# row_num=1, startindex=739121, stopindex=741816
# go=True istart=739121 iend=741816 row_num=1

# %%
dt
# Out:
# 2695

# %% [markdown]
# ## TODO The cell below reloads one of 4 wav files every loop because they require so much memory. Figure out how to avoid this in the future (ubuntu desktop is probably sufficient)
# ## but lazy loading wav files makes the most sense.

# %%
def make_wav_file(row_num, plotMe=False):
    go = True
    dt = df.iloc[row_num]['StopIndex'] - df.iloc[row_num]['StartIndex']
    if dt<460: # if the syllable is less than 5ms, try to pad it, and if it's at the start of the file, skip it 
        print(f'Syllable is too short (dt = {dt}), padding')
        # go = False
        # elif (dt < 460):
        ptadd = int((460 - dt)/2 + 1)       
        istart = df.iloc[row_num]['StartIndex']-ptadd
        if istart < 0 :
            print ('Skipping short syllable at very start of file')
            go = False
        iend = df.iloc[row_num]['StopIndex'] + ptadd
    else:
        istart = df.iloc[row_num]['StartIndex']
        iend = df.iloc[row_num]['StopIndex']
    print(f'go={go} istart={istart} iend={iend} row_num={row_num}')
    if go:
        # load just the segment of the audio file that we want
        soundSyl, sr = read_audio_section(os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])), start_frame=istart, stop_frame=iend)
        birdname = df.iloc[row_num]['SourceName']
        if len(df.iloc[row_num]['Tags']) > 0:
            calltype = df.iloc[row_num]['Tags']
        else:
            calltype = 'unknown'
        if normalize :
            maxAmp = np.abs(soundSyl).max() 
        else:
            maxAmp = 1.0

        # Save the wav file
        wav_file_name = os.path.join('wavs', f'{birdname}_{calltype}_{istart}_{iend}.wav')
        write(wav_file_name, fs, soundSyl.astype(np.float32))
        print(f'Wrote {wav_file_name}')
        return wav_file_name

# %%
# this shouldn't be necessary in this file
plotMe = False
# normalize = True
# for row_num in range(nsounds):
def make_h5_file(row_num, plotMe=False):
    go = True
    dt = df.iloc[row_num]['StopIndex'] - df.iloc[row_num]['StartIndex']
    if dt<460: # if the syllable is less than 5ms, try to pad it, and if it's at the start of the file, skip it 
        print(f'Syllable is too short (dt = {dt}), padding')
        # go = False
        # elif (dt < 460):
        ptadd = int((460 - dt)/2 + 1) # nwinlen requires a syllable of at least 460 samples to calculate biosound stuff, don't know why- Frederic had this at 250 before
        istart = df.iloc[row_num]['StartIndex']-ptadd
        if istart < 0 :
            print ('Skipping short syllable at very start of file')
            go = False
        iend = df.iloc[row_num]['StopIndex'] + ptadd
        # if (iend > len(soundIN.data) ):
        #     print ('Skipping short syllable at eend of file')
        #     go = False
    else:
        istart = df.iloc[row_num]['StartIndex']
        iend = df.iloc[row_num]['StopIndex']
    print(f'go={go} istart={istart} iend={iend} row_num={row_num}')
    if go:
        # soundIN = WavFile(file_name=os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])))
        # soundSYL = soundIN.data[istart:iend]
        # load just the segment of the audio file that we want
        # soundSyl = read_audio_section(os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])), int(istart/fs), int(iend/fs))
        soundSyl, sr = read_audio_section(os.path.join(wave_files_folder, wav_names.get(df.iloc[row_num]['SourceName'])), start_frame=istart, stop_frame=iend)

        birdname = df.iloc[row_num]['SourceName']
        if len(df.iloc[row_num]['Tags']) > 0:
            calltype = df.iloc[row_num]['Tags']
        else:
            calltype = 'unknown'
            
            
        # # Normalize if wanted- I don't want to
        # if normalize :
        #     maxAmp = np.abs(soundIN.data).max() 
        # else:
        #     maxAmp = 1.0
        
        # Create BioSound Object
        myBioSound = BioSound(soundWave=soundSyl, fs=fs, emitter=birdname, calltype = calltype)
                
        # Calculate the spectrogram and the rms
        myBioSound.spectroCalc(spec_sample_rate=1000, freq_spacing = 100, min_freq=0, max_freq=10000)
        myBioSound.rms = myBioSound.sound.std() 
        
        # Calculate amplitude enveloppe
        myBioSound.ampenv(cutoff_freq = 200, amp_sample_rate = 1000)
        
        # Calculate the power spectrum
        myBioSound.spectrum(f_high=10000)
        
        # Calculate fundamental and related values.  These are the default values.
        # For the estimation of the fundamental, four methods are available: 
        # 'AC' - Peak of the auto-correlation function
        # 'ACA' - Peak of envelope of auto-correlation function 
        # 'Cep' - First peak in cepstrum 
        # 'Stack' - Fitting of harmonic stacks (default - works well for zebra finches)
        
        myBioSound.fundest(maxFund = 6000, minFund = 300, lowFc = 200, highFc = 10000, 
                            minSaliency = 0.5, debugFig = 0, 
                            minFormantFreq = 500, maxFormantBW = 500, windowFormant = 0.1,
                            method='AC')
        
        # Calculate the MPS
        myBioSound.mpsCalc(window=0.01, Norm = True)
                    
        # save the H5 file / biosuoound object
        myBioSound.saveh5(os.path.join(base_folder, 'h5filesAmp', 'bird_%s_call_%s_%s.h5' % (birdname, calltype, row_num)))

        print(f'myBioSound.fund = {myBioSound.fund}')
        if plotMe: 
            print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
            print('                Bird %s    Call Type %s' % (myBioSound.emitter, myBioSound.type))
            myBioSound.plot(DBNOISE=50, f_low=250, f_high=10000)  
            print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')

# %%
print('done')
# Out:
# done

# %%
# from multiprocessing import Pool

# # run the h5 file creation in parallel

# def test(x):
#     print(x)
# with Pool(4) as p:
#     p.map(test, range(nsounds))


from joblib import Parallel, delayed

res = Parallel(n_jobs=5)(delayed(make_wav_file)(x) for x in range(nsounds))
#make_wav_file(0)
# Out:
# go=True istart=773851 iend=776369 row_num=2
# go=True istart=705034 iend=709502 row_num=0
# go=True istart=739121 iend=741816 row_num=1
# go=True istart=844891 iend=848558 row_num=3
# go=True istart=910549 iend=913839 row_num=4
# Wrote wavs/BroGre1354M_["1"]_705034_709502.wav
# Wrote wavs/BluGre1214F_["6"]_739121_741816.wav
# Wrote wavs/BluGre1214F_["2"]_773851_776369.wav
# Wrote wavs/BluGre1214F_["6"]_844891_848558.wav
# Wrote wavs/BroGre1354M_["5"]_910549_913839.wav
# go=True istart=915664 iend=917825 row_num=5
# Wrote wavs/BluGre1214F_["6"]_915664_917825.wav
# go=True istart=938688 iend=943405 row_num=6
# Wrote wavs/BroGre1354M_["1"]_938688_943405.wav
# go=True istart=955388 iend=958960 row_num=7
# Wrote wavs/BluGre1214F_["6"]_955388_958960.wav
# go=True istart=982338 iend=984912 row_num=8
# Wrote wavs/BluGre1214F_["0"]_982338_984912.wav
# go=True istart=1047560 iend=1050258 row_num=9
# Wrote wavs/BluGre1214F_["6"]_1047560_1050258.wav
# go=True istart=1169083 iend=1174072 row_num=10
# go=True istart=1246128 iend=1249389 row_num=11
# Wrote wavs/BroGre1354M_["4"]_1169083_1174072.wav
# Wrote wavs/BluGre1214F_["6"]_1246128_1249389.wav
# go=True istart=1303039 iend=1305757 row_num=12
# go=True istart=1425245 iend=1428007 row_num=13
# Wrote wavs/BluGre1214F_["6"]_1303039_1305757.wav
# Wrote wavs/BluGre1214F_["6"]_1425245_1428007.wav
# go=True istart=1467643 iend=1472313 row_num=14
# Wrote wavs/BroGre1354M_["1"]_1467643_1472313.wav
# go=True istart=1487256 iend=1490333 row_num=15
# Wrote wavs/BluGre1214F_["2"]_1487256_1490333.wav
# go=True istart=2093100 iend=2097644 row_num=16
# Wrote wavs/BroGre1354M_["1"]_2093100_2097644.wav
# go=True istart=2548095 iend=2552045 row_num=17
# Wrote wavs/BroGre1354M_["1"]_2548095_2552045.wav
# go=True istart=3489638 iend=3493997 row_num=18
# Wrote wavs/BroGre1354M_["1"]_3489638_3493997.wav
# go=True istart=3497899 iend=3501349 row_num=19
# Wrote wavs/BluGre1214F_["6"]_3497899_3501349.wav
# go=True istart=3556095 iend=3559832 row_num=20
# Wrote wavs/BroGre1354M_["1"]_3556095_3559832.wav
# go=True istart=3568290 iend=3571354 row_num=21
# Wrote wavs/WhiWhi1541M_["6"]_3568290_3571354.wav
# go=True istart=3861844 iend=3864094 row_num=22
# Wrote wavs/BluGre1214F_["6"]_3861844_3864094.wav
# go=True istart=3951647 iend=3954447 row_num=23
# Wrote wavs/BluGre1214F_["0"]_3951647_3954447.wav
# go=True istart=3980540 iend=3984210 row_num=24
# Wrote wavs/BluGre1214F_["6"]_3980540_3984210.wav
# go=True istart=4050255 iend=4054956 row_num=25
# Wrote wavs/BroGre1354M_["1"]_4050255_4054956.wav
# go=True istart=4064941 iend=4067385 row_num=26
# Wrote wavs/BluGre1214F_["6"]_4064941_4067385.wav
# go=True istart=4123849 iend=4128369 row_num=27
# Wrote wavs/BroGre1354M_["1"]_4123849_4128369.wav
# go=True istart=4133753 iend=4139144 row_num=28
# Wrote wavs/BroGre1354M_["1"]_4133753_4139144.wav
# go=True istart=4148928 iend=4151357 row_num=29
# Wrote wavs/BluGre1214F_["6"]_4148928_4151357.wav
# go=True istart=4250556 iend=4254887 row_num=30
# Wrote wavs/BroGre1354M_["1"]_4250556_4254887.wav
# go=True istart=4258365 iend=4263353 row_num=31
# go=True istart=4272122 iend=4276340 row_num=32
# Wrote wavs/BluGre1214F_["6"]_4258365_4263353.wav
# Wrote wavs/BroGre1354M_["5"]_4272122_4276340.wav
# go=True istart=4285902 iend=4288813 row_num=33
# go=True istart=4309478 iend=4313746 row_num=34
# Wrote wavs/BluGre1214F_["6"]_4285902_4288813.wav
# Wrote wavs/BroGre1354M_["1"]_4309478_4313746.wav
# go=True istart=4312898 iend=4317638 row_num=35
# go=True istart=4324703 iend=4327672 row_num=36
# Wrote wavs/BluGre1214F_["6"]_4324703_4327672.wav
# go=True istart=4327375 iend=4329624 row_num=37
# Wrote wavs/WhiWhi6607F_["6"]_4312898_4317638.wav
# go=True istart=4328763 iend=4332800 row_num=38
# Wrote wavs/WhiWhi1541M_["0"]_4327375_4329624.wav
# Wrote wavs/BroGre1354M_["4"]_4328763_4332800.wav
# go=True istart=4413438 iend=4418574 row_num=39
# Wrote wavs/WhiWhi6607F_["0"]_4413438_4418574.wav
# go=True istart=4416575 iend=4419371 row_num=40
# Wrote wavs/WhiWhi1541M_["5"]_4416575_4419371.wav
# go=True istart=4418076 iend=4420290 row_num=41
# go=True istart=4422265 iend=4426711 row_num=42
# Wrote wavs/BluGre1214F_["6"]_4418076_4420290.wav
# Wrote wavs/BroGre1354M_["1"]_4422265_4426711.wav
# go=True istart=4485479 iend=4490215 row_num=43
# go=True istart=4499923 iend=4502442 row_num=44
# Wrote wavs/BroGre1354M_["1"]_4485479_4490215.wav
# Wrote wavs/BluGre1214F_["6"]_4499923_4502442.wav
# go=True istart=4501762 iend=4504250 row_num=45
# go=True istart=4573869 iend=4576698 row_num=46
# Wrote wavs/BroGre1354M_["5"]_4501762_4504250.wav
# Wrote wavs/BluGre1214F_["6"]_4573869_4576698.wav
# go=True istart=4575165 iend=4579406 row_num=47
# Wrote wavs/BroGre1354M_["0"]_4575165_4579406.wav
# go=True istart=4622335 iend=4625488 row_num=48
# Wrote wavs/BluGre1214F_["6"]_4622335_4625488.wav
# go=True istart=4678954 iend=4681713 row_num=50
# go=True istart=4642683 iend=4646956 row_num=49
# Wrote wavs/BluGre1214F_["6"]_4678954_4681713.wav
# Wrote wavs/BroGre1354M_["1"]_4642683_4646956.wav
# go=True istart=4687981 iend=4692842 row_num=51
# go=True istart=4773748 iend=4777752 row_num=54
# Wrote wavs/BroGre1354M_["6"]_4687981_4692842.wav
# Wrote wavs/BroGre1354M_["1"]_4773748_4777752.wav
# go=True istart=4700093 iend=4703296 row_num=52
# go=True istart=4786320 iend=4789458 row_num=55
# Wrote wavs/BluGre1214F_["6"]_4700093_4703296.wav
# go=True istart=4740784 iend=4743210 row_num=53
# go=True istart=4876784 iend=4881224 row_num=58
# Wrote wavs/BluGre1214F_["6"]_4786320_4789458.wav
# Wrote wavs/BroGre1354M_["1"]_4876784_4881224.wav
# go=True istart=4838951 iend=4842034 row_num=56
# Wrote wavs/BluGre1214F_["6"]_4740784_4743210.wav
# go=True istart=4881433 iend=4884617 row_num=59
# Wrote wavs/BluGre1214F_["5"]_4838951_4842034.wav
# Wrote wavs/BluGre1214F_["6"]_4881433_4884617.wav
# go=True istart=4868964 iend=4874537 row_num=57
# go=True istart=4952128 iend=4955069 row_num=62
# go=True istart=4889768 iend=4892663 row_num=60
# Wrote wavs/BluGre1214F_["6"]_4952128_4955069.wav
# Wrote wavs/WhiWhi6607F_["0"]_4868964_4874537.wav
# Wrote wavs/BluGre1214F_["6"]_4889768_4892663.wav
# go=True istart=4968332 iend=4970952 row_num=63
# go=True istart=4942444 iend=4946398 row_num=61
# Wrote wavs/BroGre1354M_["6"]_4942444_4946398.wav
# Wrote wavs/BluGre1214F_["6"]_4968332_4970952.wav
# go=True istart=5066118 iend=5068672 row_num=64
# go=True istart=5096697 iend=5099525 row_num=66
# Wrote wavs/BluGre1214F_["6"]_5066118_5068672.wav
# Wrote wavs/BluGre1214F_["6"]_5096697_5099525.wav
# go=True istart=5090914 iend=5096497 row_num=65
# go=True istart=5105283 iend=5108619 row_num=67
# go=True istart=5235752 iend=5237768 row_num=70
# Wrote wavs/BluGre1214F_["6"]_5105283_5108619.wav
# Wrote wavs/WhiWhi1541M_["5"]_5090914_5096497.wav
# go=True istart=5127308 iend=5131068 row_num=68
# Wrote wavs/BluGre1214F_["0"]_5235752_5237768.wav
# go=True istart=5287828 iend=5291494 row_num=71
# Wrote wavs/BroGre1354M_["1"]_5127308_5131068.wavgo=True istart=5345496 iend=5348534 row_num=74
#
# go=True istart=5224805 iend=5229173 row_num=69
# Wrote wavs/WhiWhi1541M_["5"]_5287828_5291494.wav
# go=True istart=5299602 iend=5303816 row_num=72
# Wrote wavs/BluGre1214F_["6"]_5345496_5348534.wav
# Wrote wavs/BroGre1354M_["1"]_5224805_5229173.wav
# go=True istart=5793546 iend=5798179 row_num=75
# Wrote wavs/BroGre1354M_["1"]_5299602_5303816.wav
# go=True istart=6098242 iend=6101841 row_num=78
# Wrote wavs/BluGre1214F_["6"]_5793546_5798179.wav
# go=True istart=5331615 iend=5335371 row_num=73
# go=True istart=5922860 iend=5925872 row_num=76
# Wrote wavs/BroGre1354M_["5"]_6098242_6101841.wav
# Wrote wavs/WhiWhi1541M_["0"]_5331615_5335371.wav
# Wrote wavs/WhiWhi1541M_["0"]_5922860_5925872.wav
# go=True istart=6197479 iend=6201560 row_num=79
# go=True istart=5926137 iend=5929931 row_num=77
# go=True istart=6479539 iend=6483588 row_num=82
# Wrote wavs/BroGre1354M_["5"]_6197479_6201560.wav
# Wrote wavs/BroGre1354M_["5"]_5926137_5929931.wav
# Wrote wavs/BluGre1214F_["6"]_6479539_6483588.wav
# go=True istart=6481161 iend=6484684 row_num=83
# go=True istart=6349018 iend=6352547 row_num=80
# go=True istart=6678246 iend=6681394 row_num=86
# Wrote wavs/BroGre1354M_["5"]_6481161_6484684.wav
# Wrote wavs/BluGre1214F_["6"]_6349018_6352547.wav
# go=True istart=6643579 iend=6667335 row_num=84
# go=True istart=6350162 iend=6353481 row_num=81
# Wrote wavs/BluGre1214F_["6"]_6678246_6681394.wav
# Wrote wavs/BroGre1354M_["5"]_6350162_6353481.wav
# go=True istart=6679434 iend=6682449 row_num=87
# Wrote wavs/WhiWhi1541M_["0"]_6643579_6667335.wav
# go=True istart=6662291 iend=6666249 row_num=85
# go=True istart=6710619 iend=6714385 row_num=90
# Wrote wavs/BroGre1354M_["5"]_6679434_6682449.wav
# go=True istart=6698927 iend=6701567 row_num=88
# Wrote wavs/WhiWhi6607F_["6"]_6662291_6666249.wav
# Wrote wavs/WhiWhi1541M_["5"]_6710619_6714385.wav
# Wrote wavs/WhiWhi1541M_["6"]_6698927_6701567.wav
# go=True istart=6730087 iend=6734341 row_num=91
# go=True istart=6710585 iend=6720974 row_num=89
# go=True istart=6794359 iend=6797238 row_num=98
# Wrote wavs/BluGre1214F_["6"]_6730087_6734341.wav
# Wrote wavs/BluGre1214F_["0"]_6710585_6720974.wav
# Wrote wavs/BluGre1214F_["6"]_6794359_6797238.wav
# go=True istart=6741506 iend=6746347 row_num=92
# go=True istart=6805564 iend=6808646 row_num=99
# go=True istart=6931821 iend=6937970 row_num=106
# Wrote wavs/BroGre1354M_["1"]_6741506_6746347.wav
# go=True istart=6750316 iend=6753014 row_num=93
# Wrote wavs/BluGre1214F_["6"]_6805564_6808646.wav
# Wrote wavs/BluGre1214F_["2"]_6750316_6753014.wav
# go=True istart=6865382 iend=6868686 row_num=100
# go=True istart=6755636 iend=6765173 row_num=94
# go=True istart=7180935 iend=7184781 row_num=114
# Wrote wavs/BluGre1214F_["2"]_6931821_6937970.wav
# go=True istart=6954372 iend=6958582 row_num=107
# Wrote wavs/WhiWhi6607F_["6"]_6865382_6868686.wav
# go=True istart=6866540 iend=6869249 row_num=101
# Wrote wavs/BluGre1214F_["6"]_7180935_7184781.wav
# Wrote wavs/WhiWhi6607F_["6"]_6755636_6765173.wav
# go=True istart=7198861 iend=7203455 row_num=115
# go=True istart=6770992 iend=6773967 row_num=95
# Wrote wavs/BluGre1214F_["6"]_6954372_6958582.wav
# go=True istart=6972536 iend=6976784 row_num=108
# Wrote wavs/BluGre1214F_["2"]_6770992_6773967.wav
# go=True istart=6781378 iend=6784481 row_num=96
# Wrote wavs/WhiWhi1541M_["5"]_6866540_6869249.wav
# Wrote wavs/BroGre1354M_["5"]_7198861_7203455.wav
# go=True istart=7213176 iend=7223597 row_num=116
# go=True istart=6889962 iend=6894330 row_num=102
# Wrote wavs/BluGre1214F_["6"]_6781378_6784481.wav
# Wrote wavs/BroGre1354M_["5"]_6972536_6976784.wav
# go=True istart=6783953 iend=6788407 row_num=97
# Wrote wavs/BluGre1214F_["6"]_6889962_6894330.wav
# go=True istart=6989934 iend=6996392 row_num=109
# go=True istart=6906582 iend=6911107 row_num=103
# Wrote wavs/WhiWhi1541M_["3"]_6989934_6996392.wavWrote wavs/WhiWhi6607F_["6"]_7213176_7223597.wav
#
# Wrote wavs/BroGre1354M_["1"]_6783953_6788407.wav
# Wrote wavs/BroGre1354M_["1"]_6906582_6911107.wav
# go=True istart=7227533 iend=7232202 row_num=117
# go=True istart=7011259 iend=7016585 row_num=110
# go=True istart=6907266 iend=6908999 row_num=104
# Wrote wavs/BluGre1214F_["6"]_7011259_7016585.wav
# go=True istart=7570983 iend=7576219 row_num=122
# Wrote wavs/WhiWhi1541M_["2"]_6907266_6908999.wav
# Wrote wavs/BroGre1354M_["5"]_7227533_7232202.wav
# go=True istart=7013088 iend=7017548 row_num=111
# go=True istart=6922323 iend=6932018 row_num=105
# go=True istart=7267668 iend=7271285 row_num=118
# Wrote wavs/WhiWhi6607F_["6"]_7570983_7576219.wav
# Wrote wavs/BroGre1354M_["5"]_7013088_7017548.wav
# go=True istart=7072234 iend=7100699 row_num=112
# Wrote wavs/WhiWhi6607F_["6"]_6922323_6932018.wav
# go=True istart=7579390 iend=7582614 row_num=123
# Wrote wavs/BroGre1354M_["5"]_7267668_7271285.wav
# go=True istart=7442780 iend=7445922 row_num=119
# Wrote wavs/WhiWhi6607F_["1"]_7072234_7100699.wav
# Wrote wavs/BluGre1214F_["6"]_7579390_7582614.wav
# go=True istart=7723015 iend=7727644 row_num=130
# go=True istart=7084194 iend=7087817 row_num=113
# go=True istart=7583826 iend=7588360 row_num=124
# Wrote wavs/BroGre1354M_["5"]_7442780_7445922.wav
# Wrote wavs/BroGre1354M_["1"]_7723015_7727644.wav
# go=True istart=7455566 iend=7463209 row_num=120
# go=True istart=7724830 iend=7732637 row_num=131
# Wrote wavs/BroGre1354M_["5"]_7084194_7087817.wav
# Wrote wavs/BroGre1354M_["4"]_7583826_7588360.wav
# go=True istart=7595219 iend=7598154 row_num=125
# Wrote wavs/WhiWhi6607F_["0"]_7724830_7732637.wav
# Wrote wavs/BluGre1214F_["6"]_7595219_7598154.wav
# Wrote wavs/WhiWhi6607F_["6"]_7455566_7463209.wav
# go=True istart=7789312 iend=7795631 row_num=132
# go=True istart=7991192 iend=7994387 row_num=138
# go=True istart=7616576 iend=7620256 row_num=126
# go=True istart=7561143 iend=7564712 row_num=121
# Wrote wavs/BluGre1214F_["6"]_7991192_7994387.wav
# Wrote wavs/WhiWhi6607F_["6"]_7789312_7795631.wav
# Wrote wavs/WhiWhi1541M_["6"]_7616576_7620256.wav
# go=True istart=8005411 iend=8008408 row_num=139
# Wrote wavs/BluGre1214F_["6"]_7561143_7564712.wav
# go=True istart=7808509 iend=7814123 row_num=133
# go=True istart=7668820 iend=7674122 row_num=127
# Wrote wavs/WhiWhi1541M_["5"]_8005411_8008408.wav
# Wrote wavs/WhiWhi1541M_["5"]_7808509_7814123.wav
# go=True istart=8130369 iend=8134911 row_num=146
# go=True istart=8008849 iend=8014095 row_num=140
# Wrote wavs/WhiWhi6607F_["0"]_7668820_7674122.wav
# go=True istart=7886097 iend=7891169 row_num=134
# go=True istart=7702740 iend=7705923 row_num=128
# Wrote wavs/WhiWhi1541M_["5"]_8008849_8014095.wav
# Wrote wavs/BroGre1354M_["1"]_8130369_8134911.wav
# go=True istart=8015066 iend=8019846 row_num=141
# Wrote wavs/WhiWhi1541M_["5"]_7886097_7891169.wav
# Wrote wavs/BluGre1214F_["6"]_7702740_7705923.wav
# go=True istart=8143780 iend=8146391 row_num=147
# go=True istart=7897537 iend=7901836 row_num=135
# go=True istart=7718875 iend=7722537 row_num=129
# Wrote wavs/BluGre1214F_["6"]_8143780_8146391.wav
# Wrote wavs/BroGre1354M_["1"]_8015066_8019846.wav
# Wrote wavs/BroGre1354M_["1"]_7897537_7901836.wav
# go=True istart=8027882 iend=8047791 row_num=142
# go=True istart=8145412 iend=8148205 row_num=148
# Wrote wavs/BluGre1214F_["6"]_7718875_7722537.wav
# go=True istart=7912426 iend=7915950 row_num=136
# Wrote wavs/BroGre1354M_["0"]_8027882_8047791.wav
# Wrote wavs/BroGre1354M_["5"]_8145412_8148205.wav
# Wrote wavs/BluGre1214F_["6"]_7912426_7915950.wav
# go=True istart=8243923 iend=8246105 row_num=154
# go=True istart=8053193 iend=8057183 row_num=143
# go=True istart=8186332 iend=8189135 row_num=149
# go=True istart=7928537 iend=7933326 row_num=137
# Wrote wavs/BluGre1214F_["0"]_8243923_8246105.wav
# Wrote wavs/WhiWhi1541M_["5"]_8186332_8189135.wav
# Wrote wavs/BluGre1214F_["6"]_8053193_8057183.wav
# Wrote wavs/WhiWhi1541M_["5"]_7928537_7933326.wav
# go=True istart=8284013 iend=8286997 row_num=155
# go=True istart=8196745 iend=8230327 row_num=150
# go=True istart=8066162 iend=8070995 row_num=144
# Wrote wavs/BluGre1214F_["6"]_8284013_8286997.wav
# Wrote wavs/BroGre1354M_["4"]_8066162_8070995.wav
# go=True istart=8359442 iend=8365252 row_num=162
# go=True istart=8287175 iend=8292459 row_num=156
# Wrote wavs/BroGre1354M_["1"]_8196745_8230327.wav
# go=True istart=8104572 iend=8109744 row_num=145
# go=True istart=8200068 iend=8203528 row_num=151
# Wrote wavs/WhiWhi6607F_["2"]_8104572_8109744.wav
# Wrote wavs/WhiWhi6607F_["6"]_8287175_8292459.wav
# Wrote wavs/WhiWhi6607F_["6"]_8359442_8365252.wav
# Wrote wavs/BluGre1214F_["6"]_8200068_8203528.wav
# go=True istart=8293366 iend=8298421 row_num=157
# go=True istart=8376836 iend=8381713 row_num=163
# go=True istart=8205761 iend=8211334 row_num=152
# Wrote wavs/BroGre1354M_["1"]_8293366_8298421.wav
# Wrote wavs/BroGre1354M_["4"]_8376836_8381713.wav
# Wrote wavs/WhiWhi6607F_["6"]_8205761_8211334.wav
# go=True istart=8522145 iend=8526602 row_num=170
# go=True istart=8404427 iend=8408135 row_num=164
# go=True istart=8303322 iend=8308354 row_num=158
# go=True istart=8232499 iend=8237033 row_num=153
# Wrote wavs/BluGre1214F_["6"]_8522145_8526602.wavWrote wavs/BroGre1354M_["1"]_8303322_8308354.wav
#
# Wrote wavs/BroGre1354M_["4"]_8232499_8237033.wav
# Wrote wavs/BluGre1214F_["5"]_8404427_8408135.wav
# go=True istart=8312251 iend=8316282 row_num=159
# go=True istart=8538723 iend=8543541 row_num=171
# go=True istart=8414140 iend=8419583 row_num=165
# go=True istart=8788359 iend=8791798 row_num=186
# Wrote wavs/WhiWhi6607F_["6"]_8414140_8419583.wav
# Wrote wavs/BroGre1354M_["4"]_8538723_8543541.wav
# Wrote wavs/BluGre1214F_["6"]_8312251_8316282.wav
# go=True istart=8551718 iend=8554652 row_num=172
# go=True istart=8426594 iend=8429738 row_num=166
# go=True istart=8333774 iend=8337363 row_num=160
# Wrote wavs/WhiWhi1541M_["5"]_8788359_8791798.wav
# go=True istart=8836175 iend=8841950 row_num=187
# Wrote wavs/BluGre1214F_["6"]_8426594_8429738.wav
# Wrote wavs/BluGre1214F_["6"]_8551718_8554652.wav
# Wrote wavs/BluGre1214F_["6"]_8333774_8337363.wav
# go=True istart=8464401 iend=8468572 row_num=167
# go=True istart=8348289 iend=8350951 row_num=161
# go=True istart=8563547 iend=8569513 row_num=173
# Wrote wavs/BroGre1354M_["6"]_8836175_8841950.wav
# go=True istart=8843071 iend=8846001 row_num=188
# Wrote wavs/BroGre1354M_["1"]_8464401_8468572.wav
# Wrote wavs/WhiWhi1541M_["2"]_8348289_8350951.wav
# Wrote wavs/WhiWhi6607F_["2"]_8563547_8569513.wav
# go=True istart=8480284 iend=8483493 row_num=168
# go=True istart=8573312 iend=8575454 row_num=174
# Wrote wavs/BluGre1214F_["6"]_8843071_8846001.wav
# go=True istart=8845475 iend=8849929 row_num=189
# Wrote wavs/BluGre1214F_["6"]_8480284_8483493.wav
# Wrote wavs/BluGre1214F_["2"]_8573312_8575454.wav
# go=True istart=9203498 iend=9207981 row_num=202
# go=True istart=8498766 iend=8504264 row_num=169
# go=True istart=8604310 iend=8607243 row_num=175
# Wrote wavs/WhiWhi6607F_["0"]_8845475_8849929.wav
# Wrote wavs/BroGre1354M_["1"]_9203498_9207981.wav
# go=True istart=8854777 iend=8857701 row_num=190
# Wrote wavs/WhiWhi6607F_["6"]_8498766_8504264.wav
# Wrote wavs/BluGre1214F_["6"]_8604310_8607243.wav
# go=True istart=9232320 iend=9234940 row_num=203
# go=True istart=8629118 iend=8633780 row_num=176
# Wrote wavs/BluGre1214F_["6"]_8854777_8857701.wav
# go=True istart=8913603 iend=8919047 row_num=191
# Wrote wavs/BluGre1214F_["6"]_9232320_9234940.wav
# go=True istart=9647724 iend=9691037 row_num=218
# Wrote wavs/BroGre1354M_["4"]_8629118_8633780.wav
# go=True istart=9241063 iend=9243964 row_num=204
# go=True istart=8636905 iend=8642173 row_num=177
# Wrote wavs/WhiWhi6607F_["6"]_8913603_8919047.wav
# go=True istart=8952893 iend=8956721 row_num=192
# Wrote wavs/WhiWhi1541M_["5"]_9241063_9243964.wav
# Wrote wavs/WhiWhi6607F_["0"]_8636905_8642173.wav
# go=True istart=9289176 iend=9292081 row_num=205
# go=True istart=8639143 iend=8642179 row_num=178
# Wrote wavs/BroGre1354M_["1"]_9647724_9691037.wav
# Wrote wavs/WhiWhi1541M_["0"]_8952893_8956721.wav
# Wrote wavs/BluGre1214F_["6"]_9289176_9292081.wav
# go=True istart=9652874 iend=9655986 row_num=219
# go=True istart=8969063 iend=8973744 row_num=193
# Wrote wavs/BluGre1214F_["6"]_8639143_8642179.wav
# go=True istart=9330452 iend=9335114 row_num=206
# go=True istart=8650824 iend=8653872 row_num=179
# Wrote wavs/WhiWhi1541M_["5"]_9652874_9655986.wav
# go=True istart=9920573 iend=9923478 row_num=234
# Wrote wavs/BroGre1354M_["1"]_8969063_8973744.wav
# Wrote wavs/BroGre1354M_["1"]_9330452_9335114.wav
# go=True istart=9668513 iend=9672270 row_num=220
# go=True istart=8982679 iend=8985508 row_num=194
# go=True istart=9341054 iend=9343961 row_num=207
# Wrote wavs/BluGre1214F_["6"]_8650824_8653872.wav
# go=True istart=8685663 iend=8694128 row_num=180
# Wrote wavs/WhiWhi1541M_["5"]_9920573_9923478.wav
# Wrote wavs/WhiWhi1541M_["5"]_9668513_9672270.wav
# go=True istart=9961473 iend=9964406 row_num=235
# go=True istart=9675000 iend=9677135 row_num=221
# Wrote wavs/BluGre1214F_["6"]_9341054_9343961.wav
# Wrote wavs/BluGre1214F_["6"]_8982679_8985508.wav
# go=True istart=9341896 iend=9347136 row_num=208
# Wrote wavs/BroGre1354M_["0"]_8685663_8694128.wav
# go=True istart=9041384 iend=9044744 row_num=195
# Wrote wavs/BluGre1214F_["6"]_9675000_9677135.wav
# Wrote wavs/WhiWhi1541M_["5"]_9961473_9964406.wav
# go=True istart=8692963 iend=8698391 row_num=181
# go=True istart=9687406 iend=9690432 row_num=222
# go=True istart=10010518 iend=10014739 row_num=236
# Wrote wavs/WhiWhi6607F_["0"]_9341896_9347136.wav
# Wrote wavs/WhiWhi1541M_["6"]_9041384_9044744.wav
# Wrote wavs/WhiWhi6607F_["2"]_8692963_8698391.wav
# go=True istart=9392456 iend=9396804 row_num=209
# go=True istart=9080478 iend=9084838 row_num=196
# Wrote wavs/WhiWhi1541M_["5"]_9687406_9690432.wav
# go=True istart=8702417 iend=8707517 row_num=182
# Wrote wavs/BroGre1354M_["1"]_10010518_10014739.wav
# go=True istart=9726421 iend=9729136 row_num=223
# go=True istart=10022272 iend=10025230 row_num=237
# Wrote wavs/BroGre1354M_["4"]_9392456_9396804.wav
# Wrote wavs/BroGre1354M_["1"]_8702417_8707517.wavWrote wavs/BroGre1354M_["1"]_9080478_9084838.wav
#
# go=True istart=9409312 iend=9412258 row_num=210
# Wrote wavs/WhiWhi1541M_["5"]_9726421_9729136.wav
# Wrote wavs/BroGre1354M_["5"]_10022272_10025230.wav
# go=True istart=8711562 iend=8714435 row_num=183
# go=True istart=9088276 iend=9090938 row_num=197
# go=True istart=9733616 iend=9751513 row_num=224
# go=True istart=10041137 iend=10046711 row_num=238
# Wrote wavs/BluGre1214F_["5"]_9409312_9412258.wav
# go=True istart=9430829 iend=9433892 row_num=211
# Wrote wavs/BluGre1214F_["6"]_9088276_9090938.wav
# Wrote wavs/BluGre1214F_["2"]_8711562_8714435.wav
# Wrote wavs/BroGre1354M_["0"]_9733616_9751513.wav
# Wrote wavs/WhiWhi6607F_["6"]_10041137_10046711.wav
# go=True istart=9106606 iend=9109763 row_num=198
# go=True istart=8753718 iend=8770676 row_num=184
# go=True istart=10061033 iend=10065580 row_num=239
# Wrote wavs/WhiWhi1541M_["5"]_9430829_9433892.wav
# go=True istart=9757163 iend=9761719 row_num=225
# go=True istart=9446556 iend=9451978 row_num=212
# Wrote wavs/BroGre1354M_["1"]_9757163_9761719.wav
# go=True istart=9761838 iend=9764806 row_num=226
# Wrote wavs/BroGre1354M_["5"]_9446556_9451978.wav
# Wrote wavs/WhiWhi1541M_["6"]_9106606_9109763.wav
# Wrote wavs/BluGre1214F_["0"]_10061033_10065580.wav
# Wrote wavs/WhiWhi6607F_["1"]_8753718_8770676.wav
# Wrote wavs/WhiWhi1541M_["5"]_9761838_9764806.wav
# go=True istart=10068542 iend=10071367 row_num=240
# go=True istart=9454102 iend=9456811 row_num=213
# go=True istart=8787264 iend=8792937 row_num=185
# go=True istart=9177313 iend=9181889 row_num=199
# go=True istart=9802170 iend=9805570 row_num=227
# Wrote wavs/BroGre1354M_["5"]_10068542_10071367.wav
# Wrote wavs/BroGre1354M_["1"]_8787264_8792937.wav
# Wrote wavs/BroGre1354M_["6"]_9177313_9181889.wav
# Wrote wavs/BluGre1214F_["5"]_9454102_9456811.wav
# Wrote wavs/WhiWhi1541M_["5"]_9802170_9805570.wav
# go=True istart=10088619 iend=10093695 row_num=241
# go=True istart=9187235 iend=9190194 row_num=200
# go=True istart=9808930 iend=9813679 row_num=228
# go=True istart=9498373 iend=9502609 row_num=214
# go=True istart=10279169 iend=10281921 row_num=250
# Wrote wavs/BluGre1214F_["6"]_9187235_9190194.wav
# Wrote wavs/BroGre1354M_["1"]_9498373_9502609.wav
# Wrote wavs/BroGre1354M_["4"]_10088619_10093695.wav
# Wrote wavs/BroGre1354M_["1"]_9808930_9813679.wav
# go=True istart=9194945 iend=9200400 row_num=201
# go=True istart=9502739 iend=9505334 row_num=215
# go=True istart=9823693 iend=9826300 row_num=229
# go=True istart=10102863 iend=10105857 row_num=242
# Wrote wavs/BluGre1214F_["2"]_10279169_10281921.wav
# go=True istart=10344803 iend=10349511 row_num=251
# Wrote wavs/WhiWhi1541M_["5"]_9502739_9505334.wav
# Wrote wavs/WhiWhi6607F_["6"]_9194945_9200400.wav
# Wrote wavs/BluGre1214F_["6"]_10102863_10105857.wav
# Wrote wavs/BluGre1214F_["6"]_9823693_9826300.wav
# go=True istart=9585914 iend=9588354 row_num=216
# go=True istart=10122114 iend=10124754 row_num=243
# go=True istart=9842736 iend=9846014 row_num=230
# Wrote wavs/BroGre1354M_["1"]_10344803_10349511.wav
# Syllable is too short (dt = 167), padding
# go=True istart=10362456 iend=10362917 row_num=252
# Wrote wavs/WhiWhi1541M_["5"]_9585914_9588354.wav
# Wrote wavs/BroGre1354M_["5"]_10122114_10124754.wav
# Wrote wavs/WhiWhi1541M_["5"]_9842736_9846014.wav
# go=True istart=11135127 iend=11137858 row_num=266
# go=True istart=9619655 iend=9625044 row_num=217
# go=True istart=10163477 iend=10214422 row_num=244
# go=True istart=9894686 iend=9899634 row_num=231
# Wrote wavs/BluGre1214F_[]_10362456_10362917.wav
# Wrote wavs/WhiWhi6607F_["6"]_9619655_9625044.wav
# go=True istart=10363159 iend=10365697 row_num=253
# Wrote wavs/BroGre1354M_["1"]_9894686_9899634.wav
# Wrote wavs/BluGre1214F_["5"]_11135127_11137858.wav
# go=True istart=9902706 iend=9905636 row_num=232
# go=True istart=11141330 iend=11144757 row_num=267
# Wrote wavs/WhiWhi1541M_["0"]_10163477_10214422.wav
# Wrote wavs/BluGre1214F_["2"]_10363159_10365697.wav
# go=True istart=10176347 iend=10182535 row_num=245
# go=True istart=15246850 iend=15250980 row_num=282
# go=True istart=10365962 iend=10366522 row_num=254
# Wrote wavs/BluGre1214F_["6"]_9902706_9905636.wav
# Wrote wavs/BluGre1214F_["5"]_11141330_11144757.wav
# Wrote wavs/WhiWhi6607F_["6"]_10176347_10182535.wav
# go=True istart=9909117 iend=9913563 row_num=233
# go=True istart=11183361 iend=11188482 row_num=268
# Wrote wavs/BluGre1214F_[]_10365962_10366522.wav
# Wrote wavs/BroGre1354M_["1"]_15246850_15250980.wav
# go=True istart=10186565 iend=10189569 row_num=246
# go=True istart=15251733 iend=15255589 row_num=283
# go=True istart=10381192 iend=10387116 row_num=255
# Wrote wavs/BluGre1214F_["6"]_9909117_9913563.wav
# Wrote wavs/BroGre1354M_["1"]_11183361_11188482.wav
# Wrote wavs/BluGre1214F_["6"]_10186565_10189569.wav
# go=True istart=11184085 iend=11187373 row_num=269
# Wrote wavs/WhiWhi6607F_["6"]_10381192_10387116.wav
# go=True istart=10202548 iend=10205480 row_num=247
# Wrote wavs/BluGre1214F_["6"]_15251733_15255589.wav
# go=True istart=10389504 iend=10391535 row_num=256
# go=True istart=18649469 iend=18653332 row_num=298
# go=True istart=15364802 iend=15367939 row_num=284
# Wrote wavs/BluGre1214F_["5"]_11184085_11187373.wav
# Wrote wavs/BluGre1214F_["5"]_10202548_10205480.wav
# go=True istart=11235870 iend=11240596 row_num=270
# Wrote wavs/BroGre1354M_["6"]_15364802_15367939.wav
# go=True istart=10268622 iend=10273528 row_num=248
# Wrote wavs/WhiWhi1541M_["6"]_10389504_10391535.wav
# Wrote wavs/BluGre1214F_["6"]_18649469_18653332.wav
# go=True istart=15368708 iend=15373088 row_num=285
# go=True istart=10465727 iend=10501052 row_num=257
# go=True istart=19265361 iend=19269916 row_num=299
# Wrote wavs/BroGre1354M_["1"]_11235870_11240596.wav
# Wrote wavs/BroGre1354M_["1"]_10268622_10273528.wav
# Wrote wavs/BluGre1214F_["6"]_15368708_15373088.wav
# go=True istart=11528644 iend=11533280 row_num=271
# go=True istart=10276632 iend=10282018 row_num=249
# go=True istart=15577398 iend=15581341 row_num=286
# Wrote wavs/BroGre1354M_["1"]_19265361_19269916.wav
# Wrote wavs/WhiWhi1541M_["0"]_10465727_10501052.wav
# go=True istart=19289351 iend=19292437 row_num=300
# Wrote wavs/BroGre1354M_["1"]_11528644_11533280.wav
# go=True istart=10562466 iend=10566923 row_num=258
# Wrote wavs/BroGre1354M_["4"]_15577398_15581341.wav
# go=True istart=11573812 iend=11577111 row_num=272
# Wrote wavs/WhiWhi6607F_["6"]_10276632_10282018.wav
# go=True istart=15694089 iend=15698212 row_num=287
# Wrote wavs/BluGre1214F_["6"]_19289351_19292437.wav
# Wrote wavs/BroGre1354M_["1"]_10562466_10566923.wav
# go=True istart=19355913 iend=19360214 row_num=301
# Wrote wavs/BroGre1354M_["6"]_11573812_11577111.wav
# go=True istart=10619555 iend=10625064 row_num=259
# Wrote wavs/BluGre1214F_["6"]_15694089_15698212.wav
# go=True istart=11580918 iend=11591247 row_num=273
# go=True istart=19853527 iend=19855551 row_num=314
# go=True istart=15819788 iend=15824392 row_num=288
# Wrote wavs/BluGre1214F_["0"]_19355913_19360214.wav
# go=True istart=19365845 iend=19369454 row_num=302
# Wrote wavs/WhiWhi6607F_["0"]_10619555_10625064.wav
# Wrote wavs/WhiWhi6607F_["6"]_19853527_19855551.wav
# Wrote wavs/WhiWhi1541M_["6"]_11580918_11591247.wav
# Wrote wavs/BroGre1354M_["4"]_15819788_15824392.wav
# go=True istart=10733200 iend=10737735 row_num=260
# go=True istart=19913393 iend=19917732 row_num=315
# go=True istart=11709197 iend=11713238 row_num=274
# go=True istart=15888174 iend=15893261 row_num=289
# Wrote wavs/BluGre1214F_["6"]_19365845_19369454.wav
# go=True istart=19402986 iend=19406580 row_num=303
# Wrote wavs/WhiWhi6607F_["6"]_10733200_10737735.wav
# Wrote wavs/BroGre1354M_["6"]_19913393_19917732.wav
# Wrote wavs/BroGre1354M_["5"]_11709197_11713238.wavgo=True istart=10739363 iend=10743726 row_num=261
#
# Wrote wavs/BroGre1354M_["5"]_15888174_15893261.wav
# go=True istart=19954333 iend=19958231 row_num=316
# Wrote wavs/BluGre1214F_["0"]_19402986_19406580.wav
# go=True istart=15921621 iend=15926093 row_num=290
# go=True istart=11819280 iend=11823989 row_num=275
# go=True istart=19563202 iend=19567415 row_num=304
# Wrote wavs/BroGre1354M_["1"]_10739363_10743726.wav
# Wrote wavs/BluGre1214F_["6"]_19954333_19958231.wav
# Wrote wavs/BroGre1354M_["4"]_11819280_11823989.wav
# Wrote wavs/BroGre1354M_["4"]_15921621_15926093.wav
# Wrote wavs/BroGre1354M_["6"]_19563202_19567415.wav
# go=True istart=10994796 iend=10999016 row_num=262
# go=True istart=20004053 iend=20008362 row_num=317
# go=True istart=15954903 iend=15959184 row_num=291
# go=True istart=19571530 iend=19574519 row_num=305
# go=True istart=11968255 iend=11972977 row_num=276
# Wrote wavs/BluGre1214F_["5"]_20004053_20008362.wav
# Wrote wavs/BroGre1354M_["1"]_10994796_10999016.wav
# go=True istart=20012140 iend=20016534 row_num=318
# Wrote wavs/BroGre1354M_["5"]_15954903_15959184.wav
# Wrote wavs/BroGre1354M_["1"]_11968255_11972977.wav
# Wrote wavs/BluGre1214F_["2"]_19571530_19574519.wav
# go=True istart=11006898 iend=11009079 row_num=263
# go=True istart=14531009 iend=14535497 row_num=277
# go=True istart=17055731 iend=17063179 row_num=292
# go=True istart=19621834 iend=19625347 row_num=306
# Wrote wavs/BluGre1214F_["5"]_20012140_20016534.wav
# go=True istart=20040769 iend=20045666 row_num=319
# Wrote wavs/WhiWhi6607F_["2"]_11006898_11009079.wav
# Wrote wavs/BluGre1214F_["6"]_14531009_14535497.wav
# Wrote wavs/BluGre1214F_["6"]_17055731_17063179.wav
# Wrote wavs/BluGre1214F_["6"]_19621834_19625347.wav
# go=True istart=11007748 iend=11009994 row_num=264
# go=True istart=14541582 iend=14546687 row_num=278
# Wrote wavs/WhiWhi6607F_["0"]_20040769_20045666.wav
# go=True istart=17090524 iend=17094252 row_num=293
# go=True istart=19749457 iend=19753912 row_num=307
# go=True istart=20056570 iend=20060776 row_num=320
# Wrote wavs/BluGre1214F_["6"]_20056570_20060776.wav
# go=True istart=20110906 iend=20114535 row_num=321
# Wrote wavs/BluGre1214F_["6"]_20110906_20114535.wav
# Wrote wavs/BroGre1354M_["4"]_14541582_14546687.wav
# go=True istart=20980601 iend=20985263 row_num=322
# Wrote wavs/WhiWhi1541M_["5"]_11007748_11009994.wav
# Wrote wavs/BroGre1354M_["1"]_19749457_19753912.wav
# Wrote wavs/BroGre1354M_["5"]_17090524_17094252.wav
# go=True istart=14595104 iend=14599909 row_num=279
# go=True istart=11074614 iend=11087209 row_num=265
# go=True istart=17107223 iend=17110523 row_num=294
# go=True istart=19760897 iend=19762930 row_num=308
# Wrote wavs/BroGre1354M_["0"]_20980601_20985263.wav
# go=True istart=20997963 iend=21001798 row_num=323
# Wrote wavs/BluGre1214F_["6"]_14595104_14599909.wav
# Wrote wavs/WhiWhi6607F_["6"]_19760897_19762930.wav
# go=True istart=14605850 iend=14609182 row_num=280
# Wrote wavs/BroGre1354M_["1"]_11074614_11087209.wav
# Wrote wavs/WhiWhi1541M_["5"]_17107223_17110523.wav
# go=True istart=19764250 iend=19765530 row_num=309
# Wrote wavs/BroGre1354M_["1"]_20997963_21001798.wav
# go=True istart=18283406 iend=18288222 row_num=295
# go=True istart=21026369 iend=21031034 row_num=324
# Wrote wavs/WhiWhi1541M_["6"]_14605850_14609182.wav
# Wrote wavs/BroGre1354M_["0"]_19764250_19765530.wav
# go=True istart=14615697 iend=14619623 row_num=281
# go=True istart=21556811 iend=21561433 row_num=330
# Wrote wavs/BroGre1354M_["4"]_18283406_18288222.wav
# go=True istart=19773968 iend=19778227 row_num=310
# Wrote wavs/WhiWhi6607F_["0"]_21026369_21031034.wav
# go=True istart=18295057 iend=18297861 row_num=296
# go=True istart=21037552 iend=21040472 row_num=325
# Wrote wavs/BluGre1214F_["6"]_14615697_14619623.wav
# Wrote wavs/BroGre1354M_["4"]_21556811_21561433.wav
# Wrote wavs/BroGre1354M_["0"]_19773968_19778227.wav
# Wrote wavs/WhiWhi6607F_["6"]_18295057_18297861.wav
# go=True istart=21562770 iend=21567616 row_num=331
# Wrote wavs/BroGre1354M_["6"]_21037552_21040472.wav
# go=True istart=19825492 iend=19828354 row_num=311
# go=True istart=18624757 iend=18629412 row_num=297
# go=True istart=21115369 iend=21120594 row_num=326
# Wrote wavs/BroGre1354M_["6"]_21562770_21567616.wav
# go=True istart=21775911 iend=21781625 row_num=332
# Wrote wavs/BroGre1354M_["5"]_19825492_19828354.wav
# go=True istart=23209214 iend=23213451 row_num=362
# go=True istart=19844215 iend=19847887 row_num=312
# Wrote wavs/BroGre1354M_["1"]_18624757_18629412.wav
# Wrote wavs/BroGre1354M_["4"]_21115369_21120594.wav
# go=True istart=21437882 iend=21441342 row_num=327
# Wrote wavs/BroGre1354M_["0"]_21775911_21781625.wav
# Wrote wavs/BluGre1214F_["6"]_23209214_23213451.wav
# Wrote wavs/BroGre1354M_["5"]_19844215_19847887.wav
# go=True istart=21865271 iend=21869328 row_num=333
# go=True istart=23235958 iend=23240705 row_num=363
# go=True istart=19848740 iend=19851832 row_num=313
# go=True istart=24236579 iend=24239637 row_num=394
# Wrote wavs/BluGre1214F_["6"]_21437882_21441342.wav
# go=True istart=21505055 iend=21510208 row_num=328
# Wrote wavs/BroGre1354M_["1"]_21865271_21869328.wav
# Wrote wavs/WhiWhi1541M_["5"]_24236579_24239637.wav
# Wrote wavs/BluGre1214F_["6"]_23235958_23240705.wav
# Wrote wavs/BluGre1214F_["6"]_19848740_19851832.wav
# Wrote wavs/WhiWhi6607F_["5"]_21505055_21510208.wav
# go=True istart=21878405 iend=21883942 row_num=334
# go=True istart=24253823 iend=24258933 row_num=395
# go=True istart=23239314 iend=23244318 row_num=364
# go=True istart=21513567 iend=21518462 row_num=329
# Wrote wavs/BroGre1354M_["5"]_21878405_21883942.wav
# Wrote wavs/WhiWhi6607F_["6"]_23239314_23244318.wav
# Wrote wavs/BroGre1354M_["4"]_24253823_24258933.wav
# go=True istart=21922133 iend=21928049 row_num=335
# Wrote wavs/BroGre1354M_["1"]_21513567_21518462.wav
# go=True istart=24609236 iend=24612198 row_num=426
# go=True istart=23246750 iend=23249742 row_num=365
# go=True istart=24264072 iend=24268607 row_num=396
# Wrote wavs/BroGre1354M_["5"]_21922133_21928049.wav
# Wrote wavs/WhiWhi1541M_["5"]_23246750_23249742.wav
# Wrote wavs/WhiWhi1541M_["6"]_24609236_24612198.wav
# Wrote wavs/BluGre1214F_["6"]_24264072_24268607.wav
# go=True istart=21969141 iend=21973943 row_num=336
# go=True istart=23272238 iend=23276901 row_num=366
# go=True istart=24620213 iend=24635132 row_num=427
# go=True istart=24272798 iend=24275659 row_num=397
# go=True istart=25774403 iend=25777417 row_num=458
# Wrote wavs/WhiWhi1541M_["5"]_21969141_21973943.wav
# Wrote wavs/BroGre1354M_["4"]_23272238_23276901.wav
# Wrote wavs/WhiWhi1541M_["5"]_24272798_24275659.wav
# go=True istart=24277183 iend=24281308 row_num=398
# go=True istart=22070576 iend=22076356 row_num=337
# go=True istart=23306128 iend=23310682 row_num=367
# Wrote wavs/WhiWhi1541M_["0"]_24620213_24635132.wav
# Wrote wavs/BluGre1214F_["5"]_25774403_25777417.wav
# go=True istart=25152155 iend=25155197 row_num=428
# Wrote wavs/BluGre1214F_["6"]_23306128_23310682.wav
# Wrote wavs/BroGre1354M_["5"]_22070576_22076356.wav
# go=True istart=25820371 iend=25824960 row_num=459
# Wrote wavs/BroGre1354M_["6"]_24277183_24281308.wav
# go=True istart=23318984 iend=23324046 row_num=368
# go=True istart=22078191 iend=22082714 row_num=338
# go=True istart=24288737 iend=24291791 row_num=399
# Wrote wavs/BluGre1214F_["6"]_25152155_25155197.wav
# Wrote wavs/BroGre1354M_["5"]_25820371_25824960.wav
# go=True istart=25159949 iend=25162990 row_num=429
# Wrote wavs/BroGre1354M_["4"]_23318984_23324046.wav
# go=True istart=25833563 iend=25836770 row_num=460
# Wrote wavs/BluGre1214F_["6"]_24288737_24291791.wavWrote wavs/BroGre1354M_["1"]_22078191_22082714.wav
#
# go=True istart=23367314 iend=23371958 row_num=369
# go=True istart=24294505 iend=24304237 row_num=400
# go=True istart=22097225 iend=22101846 row_num=339
# Wrote wavs/WhiWhi1541M_["6"]_25159949_25162990.wav
# Wrote wavs/WhiWhi1541M_["6"]_25833563_25836770.wav
# go=True istart=25189198 iend=25194210 row_num=430
# Wrote wavs/BluGre1214F_["6"]_23367314_23371958.wav
# go=True istart=25839435 iend=25843825 row_num=461
# Wrote wavs/WhiWhi1541M_["0"]_24294505_24304237.wav
# Wrote wavs/BroGre1354M_["5"]_22097225_22101846.wav
# go=True istart=23377658 iend=23380957 row_num=370
# go=True istart=24316970 iend=24320859 row_num=401
# go=True istart=22278599 iend=22315846 row_num=340
# Wrote wavs/BroGre1354M_["1"]_25189198_25194210.wav
# go=True istart=25217056 iend=25220570 row_num=431
# Wrote wavs/BroGre1354M_["4"]_25839435_25843825.wav
# Wrote wavs/WhiWhi1541M_["5"]_23377658_23380957.wav
# Wrote wavs/WhiWhi6607F_["5"]_24316970_24320859.wav
# go=True istart=25917910 iend=25922314 row_num=462
# go=True istart=23383349 iend=23388125 row_num=371
# go=True istart=24329939 iend=24334999 row_num=402
# Wrote wavs/BluGre1214F_["6"]_25217056_25220570.wav
# Wrote wavs/WhiWhi6607F_["0"]_22278599_22315846.wav
# go=True istart=25227089 iend=25229998 row_num=432
# go=True istart=22321871 iend=22326112 row_num=341
# Wrote wavs/BluGre1214F_["0"]_23383349_23388125.wav
# Wrote wavs/BroGre1354M_["4"]_25917910_25922314.wav
# Wrote wavs/WhiWhi6607F_["6"]_24329939_24334999.wav
# go=True istart=23386695 iend=23390797 row_num=372
# go=True istart=25927715 iend=25930567 row_num=463
# go=True istart=24336113 iend=24355618 row_num=403
# Wrote wavs/WhiWhi1541M_["0"]_25227089_25229998.wav
# Wrote wavs/BluGre1214F_["6"]_22321871_22326112.wav
# go=True istart=25247791 iend=25253230 row_num=433
# Wrote wavs/BroGre1354M_["1"]_23386695_23390797.wav
# go=True istart=22607040 iend=22609635 row_num=342
# Wrote wavs/WhiWhi1541M_["5"]_25927715_25930567.wav
# go=True istart=23507629 iend=23510923 row_num=373
# Wrote wavs/WhiWhi6607F_["1"]_24336113_24355618.wav
# go=True istart=25933198 iend=25936033 row_num=464
# Wrote wavs/WhiWhi6607F_["6"]_25247791_25253230.wav
# go=True istart=24342321 iend=24347074 row_num=404
# Wrote wavs/WhiWhi6607F_["0"]_22607040_22609635.wav
# go=True istart=25258656 iend=25261908 row_num=434
# go=True istart=22655202 iend=22729850 row_num=343
# Wrote wavs/WhiWhi1541M_["5"]_23507629_23510923.wav
# Wrote wavs/BluGre1214F_["6"]_25933198_25936033.wav
# Wrote wavs/BroGre1354M_["1"]_24342321_24347074.wav
# go=True istart=25944820 iend=25950772 row_num=465
# go=True istart=23514760 iend=23519147 row_num=374
# Wrote wavs/BluGre1214F_["6"]_25258656_25261908.wav
# go=True istart=24350249 iend=24354890 row_num=405
# go=True istart=25272896 iend=25275839 row_num=435
# Wrote wavs/WhiWhi6607F_["6"]_25944820_25950772.wav
# Wrote wavs/BluGre1214F_["6"]_23514760_23519147.wav
# Wrote wavs/WhiWhi1541M_["0"]_22655202_22729850.wav
# go=True istart=25963408 iend=25968205 row_num=466
# go=True istart=23654628 iend=23658038 row_num=375
# go=True istart=23026077 iend=23029391 row_num=344
# Wrote wavs/WhiWhi1541M_["6"]_25272896_25275839.wav
# Wrote wavs/BluGre1214F_["6"]_24350249_24354890.wav
# go=True istart=25291240 iend=25295852 row_num=436
# go=True istart=24358829 iend=24362995 row_num=406
# Wrote wavs/WhiWhi1541M_["5"]_23654628_23658038.wav
# Wrote wavs/BroGre1354M_["1"]_25963408_25968205.wav
# Wrote wavs/BluGre1214F_["6"]_24358829_24362995.wav
# go=True istart=23659313 iend=23664586 row_num=376
# go=True istart=25968218 iend=25972911 row_num=467
# go=True istart=24363548 iend=24367070 row_num=407
# Wrote wavs/WhiWhi1541M_["5"]_23026077_23029391.wavWrote wavs/BroGre1354M_["4"]_25291240_25295852.wav
#
# go=True istart=25298688 iend=25302387 row_num=437
# Wrote wavs/WhiWhi6607F_["6"]_25968218_25972911.wav
# go=True istart=23038933 iend=23043449 row_num=345
# Wrote wavs/BroGre1354M_["4"]_23659313_23664586.wav
# Wrote wavs/BroGre1354M_["6"]_24363548_24367070.wav
# go=True istart=25987814 iend=26021447 row_num=468
# go=True istart=23664693 iend=23669560 row_num=377
# go=True istart=24367423 iend=24371634 row_num=408
# Wrote wavs/BroGre1354M_["4"]_23038933_23043449.wav
# Wrote wavs/WhiWhi6607F_["6"]_25298688_25302387.wav
# go=True istart=25356057 iend=25359408 row_num=438
# go=True istart=23061869 iend=23070045 row_num=346
# Wrote wavs/BluGre1214F_["6"]_23664693_23669560.wav
# Wrote wavs/BroGre1354M_["6"]_24367423_24371634.wav
# Wrote wavs/WhiWhi1541M_["0"]_25987814_26021447.wav
# go=True istart=25994560 iend=25996952 row_num=469
# go=True istart=24393425 iend=24397361 row_num=409
# go=True istart=23736018 iend=23739813 row_num=378
# Wrote wavs/BluGre1214F_["6"]_25356057_25359408.wav
# Wrote wavs/BroGre1354M_["3"]_23061869_23070045.wav
# go=True istart=25379222 iend=25383939 row_num=439
# go=True istart=23070025 iend=23081338 row_num=347
# Wrote wavs/BroGre1354M_["0"]_25994560_25996952.wav
# go=True istart=26004931 iend=26007134 row_num=470
# Wrote wavs/BroGre1354M_["6"]_24393425_24397361.wav
# Wrote wavs/BluGre1214F_["6"]_23736018_23739813.wav
# go=True istart=23745916 iend=23750815 row_num=379go=True istart=24397722 iend=24402273 row_num=410
#
# Wrote wavs/BluGre1214F_["6"]_26004931_26007134.wav
# Wrote wavs/WhiWhi6607F_["6"]_23070025_23081338.wav
# Wrote wavs/BroGre1354M_["4"]_25379222_25383939.wav
# go=True istart=26021431 iend=26024557 row_num=471
# go=True istart=23079085 iend=23086866 row_num=348
# go=True istart=25388341 iend=25392704 row_num=440
# Wrote wavs/BroGre1354M_["6"]_24397722_24402273.wav
# go=True istart=24418037 iend=24422474 row_num=411
# Wrote wavs/BroGre1354M_["4"]_23745916_23750815.wav
# Wrote wavs/BluGre1214F_["2"]_26021431_26024557.wavWrote wavs/BroGre1354M_["5"]_23079085_23086866.wav
#
# Wrote wavs/BluGre1214F_["6"]_25388341_25392704.wav
# go=True istart=23763341 iend=23767735 row_num=380
# go=True istart=23084729 iend=23089383 row_num=349
# go=True istart=25420937 iend=25424145 row_num=441
# Wrote wavs/BluGre1214F_["6"]_24418037_24422474.wav
# go=True istart=26028819 iend=26032199 row_num=472
# go=True istart=24429026 iend=24437422 row_num=412
# Wrote wavs/BluGre1214F_["6"]_23763341_23767735.wav
# go=True istart=23782611 iend=23802078 row_num=381
# Wrote wavs/BroGre1354M_["3"]_26028819_26032199.wavWrote wavs/BluGre1214F_["5"]_23084729_23089383.wav
#
# Wrote wavs/BluGre1214F_["6"]_25420937_25424145.wav
# go=True istart=26032157 iend=26036459 row_num=473
# go=True istart=23100463 iend=23106126 row_num=350
# Wrote wavs/BroGre1354M_["5"]_24429026_24437422.wav
# go=True istart=25446319 iend=25488122 row_num=442
# go=True istart=24435522 iend=24454139 row_num=413
# Wrote wavs/WhiWhi6607F_["1"]_23782611_23802078.wav
# go=True istart=23801541 iend=23805901 row_num=382
# Wrote wavs/WhiWhi6607F_["5"]_26032157_26036459.wav
# Wrote wavs/BroGre1354M_["4"]_23100463_23106126.wav
# go=True istart=23114057 iend=23118421 row_num=351
# Wrote wavs/BluGre1214F_["0"]_25446319_25488122.wav
# go=True istart=26046040 iend=26048873 row_num=474
# go=True istart=25500001 iend=25503289 row_num=443
# Wrote wavs/BroGre1354M_["1"]_23801541_23805901.wav
# go=True istart=23810075 iend=23814891 row_num=383
# Wrote wavs/BluGre1214F_["6"]_26046040_26048873.wavWrote wavs/WhiWhi6607F_["0"]_23114057_23118421.wav
#
# Wrote wavs/BluGre1214F_["1"]_24435522_24454139.wavWrote wavs/BluGre1214F_["6"]_25500001_25503289.wav
#
# go=True istart=26059668 iend=26064852 row_num=475
# go=True istart=23114618 iend=23115767 row_num=352
# go=True istart=25524237 iend=25534888 row_num=444
# go=True istart=24449663 iend=24462094 row_num=414
# Wrote wavs/WhiWhi6607F_["6"]_23810075_23814891.wav
# go=True istart=23834675 iend=23839311 row_num=384
# Wrote wavs/WhiWhi6607F_["6"]_26059668_26064852.wav
# Wrote wavs/BroGre1354M_[]_23114618_23115767.wav
# Wrote wavs/WhiWhi1541M_["0"]_24449663_24462094.wav
# go=True istart=26068273 iend=26073115 row_num=476
# Wrote wavs/BroGre1354M_["1"]_25524237_25534888.wav
# Wrote wavs/WhiWhi6607F_["6"]_23834675_23839311.wav
# go=True istart=23120407 iend=23133551 row_num=353
# go=True istart=24466764 iend=24470263 row_num=415
# go=True istart=25536371 iend=25539263 row_num=445
# go=True istart=23843205 iend=23847258 row_num=385
# Wrote wavs/BroGre1354M_["4"]_26068273_26073115.wav
# Wrote wavs/WhiWhi1541M_["5"]_24466764_24470263.wav
# Wrote wavs/WhiWhi6607F_["6"]_23120407_23133551.wav
# go=True istart=26079311 iend=26095270 row_num=477
# Wrote wavs/BluGre1214F_["6"]_25536371_25539263.wav
# go=True istart=24481229 iend=24486507 row_num=416
# go=True istart=23135303 iend=23140431 row_num=354
# Wrote wavs/BluGre1214F_["6"]_23843205_23847258.wav
# go=True istart=25562852 iend=25567427 row_num=446
# go=True istart=23854095 iend=23858874 row_num=386
# Wrote wavs/WhiWhi6607F_["0"]_26079311_26095270.wav
# Wrote wavs/BroGre1354M_["4"]_24481229_24486507.wav
# Wrote wavs/BluGre1214F_["2"]_23135303_23140431.wav
# Wrote wavs/BroGre1354M_["4"]_25562852_25567427.wav
# go=True istart=24520448 iend=24523973 row_num=417
# go=True istart=26109847 iend=26112777 row_num=478
# go=True istart=25563669 iend=25566373 row_num=447
# Wrote wavs/BroGre1354M_["1"]_23854095_23858874.wav
# go=True istart=23140747 iend=23146099 row_num=355
# go=True istart=23906835 iend=23909837 row_num=387
# Wrote wavs/BluGre1214F_["6"]_26109847_26112777.wav
# Wrote wavs/BroGre1354M_["0"]_23140747_23146099.wav
# go=True istart=26120144 iend=26123949 row_num=479
# Wrote wavs/WhiWhi1541M_["6"]_24520448_24523973.wav
# Wrote wavs/BluGre1214F_["2"]_25563669_25566373.wav
# go=True istart=23148766 iend=23153378 row_num=356
# go=True istart=24524353 iend=24542880 row_num=418
# go=True istart=25570324 iend=25587297 row_num=448
# Wrote wavs/BroGre1354M_["6"]_26120144_26123949.wav
# Wrote wavs/WhiWhi1541M_["5"]_23906835_23909837.wav
# go=True istart=26124273 iend=26128420 row_num=480
# Wrote wavs/BroGre1354M_["4"]_23148766_23153378.wav
# go=True istart=23925475 iend=23929372 row_num=388
# go=True istart=23160222 iend=23164247 row_num=357
# Wrote wavs/WhiWhi1541M_["0"]_24524353_24542880.wavWrote wavs/BroGre1354M_["6"]_26124273_26128420.wav
#
# Wrote wavs/BluGre1214F_["0"]_25570324_25587297.wav
# Wrote wavs/BluGre1214F_["6"]_23925475_23929372.wav
# go=True istart=26133993 iend=26137248 row_num=481
# Wrote wavs/BluGre1214F_["6"]_23160222_23164247.wav
# go=True istart=25597976 iend=25600909 row_num=449
# go=True istart=23935779 iend=23940656 row_num=389
# go=True istart=24538283 iend=24543078 row_num=419
# go=True istart=23176675 iend=23181805 row_num=358
# Wrote wavs/BroGre1354M_["1"]_23935779_23940656.wav
# Wrote wavs/BluGre1214F_["6"]_26133993_26137248.wav
# Wrote wavs/BluGre1214F_["6"]_25597976_25600909.wav
# Wrote wavs/BluGre1214F_["6"]_23176675_23181805.wav
# Wrote wavs/BluGre1214F_["6"]_24538283_24543078.wav
# go=True istart=25611295 iend=25614252 row_num=450go=True istart=23181121 iend=23186602 row_num=359
#
# go=True istart=24546413 iend=24552069 row_num=420
# go=True istart=26184461 iend=26189905 row_num=482
# go=True istart=23942719 iend=23948060 row_num=390
# Wrote wavs/BluGre1214F_["2"]_25611295_25614252.wav
# Wrote wavs/BroGre1354M_["4"]_23181121_23186602.wav
# go=True istart=25630258 iend=25633513 row_num=451
# Wrote wavs/WhiWhi6607F_["6"]_26184461_26189905.wav
# Wrote wavs/BroGre1354M_["1"]_24546413_24552069.wav
# Wrote wavs/WhiWhi6607F_["6"]_23942719_23948060.wav
# go=True istart=23189152 iend=23196718 row_num=360
# go=True istart=26971958 iend=26976995 row_num=483
# go=True istart=23986162 iend=23991365 row_num=391
# go=True istart=24556035 iend=24559980 row_num=421
# Wrote wavs/BluGre1214F_["2"]_25630258_25633513.wav
# go=True istart=25656059 iend=25659106 row_num=452
# Wrote wavs/BroGre1354M_["5"]_25656059_25659106.wavWrote wavs/BluGre1214F_["6"]_24556035_24559980.wav
#
# Wrote wavs/WhiWhi6607F_["6"]_23189152_23196718.wav
# Wrote wavs/WhiWhi6607F_["6"]_26971958_26976995.wav
# Wrote wavs/WhiWhi6607F_["6"]_23986162_23991365.wav
# go=True istart=25658708 iend=25661679 row_num=453
# go=True istart=23197434 iend=23206727 row_num=361
# go=True istart=24567444 iend=24568872 row_num=422
# go=True istart=27053228 iend=27058001 row_num=484
# go=True istart=24001224 iend=24025826 row_num=392
# Wrote wavs/BluGre1214F_["6"]_25658708_25661679.wav
# Wrote wavs/BroGre1354M_["3"]_23197434_23206727.wav
# Wrote wavs/BroGre1354M_["5"]_24567444_24568872.wav
# go=True istart=25697676 iend=25702223 row_num=454
# Wrote wavs/WhiWhi6607F_["6"]_27053228_27058001.wav
# Wrote wavs/BroGre1354M_["1"]_24001224_24025826.wavgo=True istart=24569987 iend=24574169 row_num=423
#
# go=True istart=27063852 iend=27066982 row_num=485
# go=True istart=24030395 iend=24034503 row_num=393
# Wrote wavs/BroGre1354M_["4"]_25697676_25702223.wav
# Wrote wavs/BroGre1354M_["6"]_24569987_24574169.wav
# go=True istart=24591467 iend=24594613 row_num=424
# go=True istart=25708486 iend=25711544 row_num=455
# go=True istart=27149997 iend=27154775 row_num=490
# Wrote wavs/BluGre1214F_["6"]_24030395_24034503.wav
# Wrote wavs/BluGre1214F_["6"]_27063852_27066982.wav
# Wrote wavs/BroGre1354M_["5"]_24591467_24594613.wav
# go=True istart=27071001 iend=27076109 row_num=486
# Wrote wavs/BluGre1214F_["6"]_25708486_25711544.wav
# go=True istart=24604485 iend=24607098 row_num=425
# Wrote wavs/BluGre1214F_["6"]_27149997_27154775.wav
# go=True istart=27200052 iend=27207067 row_num=491
# ...
# go=True istart=277610356 iend=277619041 row_num=4210
# go=True istart=276393075 iend=276397356 row_num=4182
# Wrote wavs/WhiWhi6607F_["6"]_277084784_277086991.wav
# Wrote wavs/WhiWhi1541M_["5"]_276621373_276624463.wav
# go=True istart=277400157 iend=277405034 row_num=4203
# go=True istart=276628424 iend=276631457 row_num=4190
# Wrote wavs/WhiWhi1541M_["0"]_276876671_276917602.wav
# Wrote wavs/BroGre1354M_["5"]_277610356_277619041.wav
# Wrote wavs/BroGre1354M_["6"]_276393075_276397356.wav
# go=True istart=276906786 iend=276911236 row_num=4196
# go=True istart=277617507 iend=277620299 row_num=4211
# Wrote wavs/BroGre1354M_["1"]_277400157_277405034.wav
# Wrote wavs/BluGre1214F_["6"]_276628424_276631457.wav
# go=True istart=277433706 iend=277438170 row_num=4204
# go=True istart=276634234 iend=276639835 row_num=4191
# Wrote wavs/BroGre1354M_["4"]_276906786_276911236.wav
# Wrote wavs/WhiWhi6607F_["6"]_277617507_277620299.wav
# go=True istart=276988400 iend=276991287 row_num=4197
# go=True istart=277892249 iend=277900558 row_num=4219
# Wrote wavs/BluGre1214F_["6"]_277433706_277438170.wav
# go=True istart=277669663 iend=277673659 row_num=4212
# Wrote wavs/WhiWhi6607F_["0"]_276634234_276639835.wav
# go=True istart=277477648 iend=277529395 row_num=4205
# Wrote wavs/BluGre1214F_["6"]_276988400_276991287.wav
# Wrote wavs/BroGre1354M_["5"]_277892249_277900558.wav
# go=True istart=277000109 iend=277004965 row_num=4198
# Wrote wavs/BluGre1214F_["6"]_277669663_277673659.wav
# go=True istart=277901130 iend=277913778 row_num=4220
# go=True istart=277679002 iend=277687151 row_num=4213
# go=True istart=278991711 iend=278994600 row_num=4228
# Wrote wavs/WhiWhi6607F_["1"]_277477648_277529395.wav
# Wrote wavs/BroGre1354M_["4"]_277000109_277004965.wav
# go=True istart=277503195 iend=277511404 row_num=4206
# Wrote wavs/BroGre1354M_["5"]_277679002_277687151.wav
# go=True istart=277022121 iend=277026559 row_num=4199
# Wrote wavs/WhiWhi6607F_["6"]_278991711_278994600.wav
# go=True istart=277691104 iend=277701508 row_num=4214
# Wrote wavs/WhiWhi6607F_["6"]_277901130_277913778.wav
# Wrote wavs/BluGre1214F_["5"]_277503195_277511404.wav
# go=True istart=279021531 iend=279025891 row_num=4229
# go=True istart=277964893 iend=277968734 row_num=4221
# Wrote wavs/BluGre1214F_["6"]_277022121_277026559.wav
# go=True istart=277557495 iend=277566160 row_num=4207
# go=True istart=277034246 iend=277041349 row_num=4200
# Wrote wavs/WhiWhi6607F_["6"]_277691104_277701508.wav
# Wrote wavs/BluGre1214F_["6"]_279021531_279025891.wav
# Wrote wavs/BluGre1214F_["3"]_277964893_277968734.wav
# Wrote wavs/BroGre1354M_["5"]_277557495_277566160.wav
# go=True istart=277718243 iend=277722229 row_num=4215
# go=True istart=279033223 iend=279036302 row_num=4230
# Wrote wavs/BroGre1354M_["3"]_277034246_277041349.wavgo=True istart=278006586 iend=278010094 row_num=4222
#
# go=True istart=277569914 iend=277579417 row_num=4208
# Wrote wavs/BluGre1214F_["6"]_277718243_277722229.wav
# Wrote wavs/BluGre1214F_["6"]_278006586_278010094.wav
# Wrote wavs/WhiWhi6607F_["6"]_277569914_277579417.wav
# go=True istart=277808048 iend=277860052 row_num=4216
# Wrote wavs/WhiWhi6607F_["6"]_279033223_279036302.wav
# go=True istart=280353449 iend=280359950 row_num=4237
# go=True istart=277603353 iend=277607679 row_num=4209
# go=True istart=278020665 iend=278028834 row_num=4223
# go=True istart=279044451 iend=279052531 row_num=4231
# Wrote wavs/WhiWhi1541M_["5"]_280353449_280359950.wav
# Wrote wavs/BluGre1214F_["6"]_277603353_277607679.wav
# Wrote wavs/BroGre1354M_["5"]_278020665_278028834.wav
# Wrote wavs/BroGre1354M_["1"]_277808048_277860052.wav
# Wrote wavs/BroGre1354M_["5"]_279044451_279052531.wav
# go=True istart=280392344 iend=280395788 row_num=4238
# go=True istart=278028372 iend=278039276 row_num=4224
# go=True istart=277839587 iend=277852541 row_num=4217
# go=True istart=279054323 iend=279057446 row_num=4232
# Wrote wavs/WhiWhi1541M_["5"]_280392344_280395788.wav
# go=True istart=280976047 iend=280980382 row_num=4246
# Wrote wavs/WhiWhi6607F_["6"]_278028372_278039276.wav
# Wrote wavs/WhiWhi6607F_["6"]_277839587_277852541.wav
# go=True istart=280478630 iend=280483300 row_num=4239
# Wrote wavs/BluGre1214F_["5"]_279054323_279057446.wav
# go=True istart=278110411 iend=278114567 row_num=4225
# go=True istart=277862304 iend=277867121 row_num=4218
# go=True istart=279067109 iend=279070071 row_num=4233
# Wrote wavs/BluGre1214F_["6"]_280976047_280980382.wav
# go=True istart=281049479 iend=281054095 row_num=4247
# Wrote wavs/BluGre1214F_["6"]_280478630_280483300.wav
# go=True istart=280529427 iend=280533228 row_num=4240
# Wrote wavs/BluGre1214F_["6"]_277862304_277867121.wav
# Wrote wavs/BluGre1214F_["6"]_278110411_278114567.wav
# Wrote wavs/BroGre1354M_["5"]_281049479_281054095.wav
# Wrote wavs/WhiWhi6607F_["2"]_279067109_279070071.wav
# Wrote wavs/BluGre1214F_["6"]_280529427_280533228.wav
# go=True istart=281064384 iend=281070173 row_num=4248
# go=True istart=278954549 iend=278962291 row_num=4226
# go=True istart=279131024 iend=279139221 row_num=4234
# go=True istart=280552916 iend=280557601 row_num=4241
# go=True istart=281193996 iend=281199130 row_num=4255
# Wrote wavs/BroGre1354M_["5"]_281064384_281070173.wav
# Wrote wavs/BroGre1354M_["5"]_279131024_279139221.wav
# Wrote wavs/BroGre1354M_["3"]_278954549_278962291.wav
# go=True istart=279132356 iend=279137200 row_num=4235
# Wrote wavs/BroGre1354M_["1"]_280552916_280557601.wav
# go=True istart=278966025 iend=278975437 row_num=4227
# go=True istart=281073035 iend=281077382 row_num=4249
# go=True istart=280564132 iend=280567815 row_num=4242Wrote wavs/BluGre1214F_["6"]_281193996_281199130.wav
#
# go=True istart=281227542 iend=281232147 row_num=4256
# Wrote wavs/WhiWhi1541M_["5"]_279132356_279137200.wav
# Wrote wavs/BluGre1214F_["6"]_281073035_281077382.wav
# Wrote wavs/BluGre1214F_["6"]_280564132_280567815.wav
# Wrote wavs/WhiWhi6607F_["6"]_278966025_278975437.wav
# go=True istart=280342629 iend=280346761 row_num=4236
# go=True istart=281088479 iend=281093424 row_num=4250
# go=True istart=280566970 iend=280571331 row_num=4243
# Wrote wavs/BroGre1354M_["5"]_281227542_281232147.wav
# go=True istart=289803009 iend=289807658 row_num=4257
# Wrote wavs/BroGre1354M_["5"]_281088479_281093424.wav
# Wrote wavs/WhiWhi1541M_["5"]_280342629_280346761.wavgo=True istart=292384434 iend=292389592 row_num=4264
# go=True istart=281119833 iend=281123754 row_num=4251
#
# Wrote wavs/WhiWhi6607F_["5"]_280566970_280571331.wav
# Wrote wavs/BroGre1354M_["1"]_289803009_289807658.wav
# go=True istart=280712331 iend=280716002 row_num=4244
# go=True istart=289974416 iend=289979094 row_num=4258
# Wrote wavs/BluGre1214F_["6"]_281119833_281123754.wav
# Wrote wavs/WhiWhi6607F_["0"]_292384434_292389592.wav
# go=True istart=281157990 iend=281163630 row_num=4252
# go=True istart=292519840 iend=292524420 row_num=4265
# Wrote wavs/BluGre1214F_["6"]_280712331_280716002.wav
# Wrote wavs/BroGre1354M_["6"]_289974416_289979094.wav
# go=True istart=280960814 iend=280965880 row_num=4245
# Wrote wavs/BroGre1354M_["5"]_281157990_281163630.wav
# go=True istart=290108033 iend=290112649 row_num=4259
# Wrote wavs/BluGre1214F_["5"]_292519840_292524420.wav
# go=True istart=281167702 iend=281172412 row_num=4253
# go=True istart=292858174 iend=292862296 row_num=4266
# Wrote wavs/BroGre1354M_["5"]_280960814_280965880.wav
# go=True istart=293030181 iend=293034360 row_num=4273
# Wrote wavs/BluGre1214F_["6"]_281167702_281172412.wav
# go=True istart=281184943 iend=281189067 row_num=4254
# go=True istart=294037764 iend=294043848 row_num=4282
# Wrote wavs/BluGre1214F_["0"]_293030181_293034360.wav
# Wrote wavs/BroGre1354M_["6"]_290108033_290112649.wav
# Wrote wavs/BroGre1354M_["6"]_292858174_292862296.wav
# Wrote wavs/BroGre1354M_["1"]_281184943_281189067.wav
# go=True istart=293044379 iend=293048805 row_num=4274
# go=True istart=290522385 iend=290526454 row_num=4260
# go=True istart=292877637 iend=292881448 row_num=4267
# Wrote wavs/WhiWhi6607F_["0"]_294037764_294043848.wav
# go=True istart=294089833 iend=294094444 row_num=4283
# Wrote wavs/BroGre1354M_["1"]_293044379_293048805.wav
# Wrote wavs/BluGre1214F_["5"]_290522385_290526454.wav
# Wrote wavs/BluGre1214F_["5"]_292877637_292881448.wav
# go=True istart=293070745 iend=293074055 row_num=4275
# go=True istart=290924656 iend=290928009 row_num=4261
# go=True istart=295468805 iend=295473387 row_num=4291
# go=True istart=292902090 iend=292907171 row_num=4268
# Wrote wavs/BroGre1354M_["4"]_294089833_294094444.wav
# Wrote wavs/BluGre1214F_["6"]_293070745_293074055.wav
# go=True istart=294096704 iend=294099707 row_num=4284
# Wrote wavs/WhiWhi6607F_["6"]_295468805_295473387.wav
# Wrote wavs/WhiWhi1541M_["5"]_290924656_290928009.wav
# Wrote wavs/BroGre1354M_["4"]_292902090_292907171.wav
# go=True istart=293077784 iend=293082774 row_num=4276
# go=True istart=295482599 iend=295485949 row_num=4292
# go=True istart=290985143 iend=290986610 row_num=4262
# go=True istart=292946601 iend=292951493 row_num=4269
# Wrote wavs/WhiWhi1541M_["6"]_294096704_294099707.wav
# Wrote wavs/BroGre1354M_["4"]_293077784_293082774.wav
# go=True istart=294125334 iend=294130679 row_num=4285
# Wrote wavs/BluGre1214F_["6"]_295482599_295485949.wav
# Wrote wavs/BluGre1214F_["5"]_290985143_290986610.wav
# Wrote wavs/BroGre1354M_["1"]_292946601_292951493.wav
# go=True istart=293120124 iend=293125363 row_num=4277
# go=True istart=290987192 iend=290989133 row_num=4263
# go=True istart=295497196 iend=295505366 row_num=4293
# go=True istart=292961067 iend=292965602 row_num=4270
# Wrote wavs/WhiWhi6607F_["6"]_294125334_294130679.wav
# go=True istart=294139592 iend=294143994 row_num=4286
# Wrote wavs/BluGre1214F_["6"]_293120124_293125363.wav
# Wrote wavs/BluGre1214F_["2"]_290987192_290989133.wav
# Wrote wavs/BroGre1354M_["3"]_295497196_295505366.wav
# Wrote wavs/BluGre1214F_["6"]_292961067_292965602.wav
# go=True istart=293126510 iend=293131352 row_num=4278
# Wrote wavs/BroGre1354M_["1"]_294139592_294143994.wav
# go=True istart=295501062 iend=295503933 row_num=4294
# go=True istart=292973708 iend=292978573 row_num=4271
# go=True istart=295395289 iend=295402177 row_num=4287
# Wrote wavs/BroGre1354M_["4"]_293126510_293131352.wav
# go=True istart=295620958 iend=295624360 row_num=4300
# go=True istart=293143590 iend=293147782 row_num=4279
# Wrote wavs/BluGre1214F_["6"]_295501062_295503933.wav
# Wrote wavs/BroGre1354M_["3"]_292973708_292978573.wav
# Wrote wavs/WhiWhi6607F_["6"]_295395289_295402177.wav
# go=True istart=292998307 iend=293003064 row_num=4272
# go=True istart=295516740 iend=295520037 row_num=4295
# go=True istart=295417496 iend=295421562 row_num=4288
# Wrote wavs/WhiWhi1541M_["5"]_295620958_295624360.wav
# Wrote wavs/BluGre1214F_["6"]_293143590_293147782.wav
# go=True istart=295642994 iend=295648640 row_num=4301
# go=True istart=293857023 iend=293861705 row_num=4280
# Wrote wavs/BluGre1214F_["6"]_292998307_293003064.wav
# Wrote wavs/BluGre1214F_["6"]_295516740_295520037.wav
# Wrote wavs/BroGre1354M_["0"]_295417496_295421562.wav
# go=True istart=295551210 iend=295556601 row_num=4296
# go=True istart=295439300 iend=295443997 row_num=4289
# Wrote wavs/WhiWhi6607F_["6"]_295642994_295648640.wav
# Wrote wavs/BroGre1354M_["5"]_293857023_293861705.wav
# go=True istart=293996283 iend=293999909 row_num=4281
# go=True istart=295654667 iend=295658740 row_num=4302
# Wrote wavs/BroGre1354M_["4"]_295551210_295556601.wav
# go=True istart=295798749 iend=295801958 row_num=4309
# Wrote wavs/BluGre1214F_["6"]_295439300_295443997.wav
# go=True istart=295561066 iend=295567047 row_num=4297
# go=True istart=295466329 iend=295469860 row_num=4290
# Wrote wavs/BroGre1354M_["1"]_295654667_295658740.wav
# Wrote wavs/WhiWhi1541M_["5"]_293996283_293999909.wav
# go=True istart=295671949 iend=295675007 row_num=4303
# Wrote wavs/BluGre1214F_["6"]_295798749_295801958.wav
# Wrote wavs/WhiWhi1541M_["3"]_295561066_295567047.wav
# Wrote wavs/WhiWhi1541M_["5"]_295466329_295469860.wav
# go=True istart=295872286 iend=295878666 row_num=4310
# Wrote wavs/BluGre1214F_["5"]_295671949_295675007.wav
# go=True istart=295565095 iend=295568223 row_num=4298
# go=True istart=296677824 iend=296742216 row_num=4318
# go=True istart=295686918 iend=295690606 row_num=4304
# Wrote wavs/WhiWhi1541M_["5"]_295872286_295878666.wav
# Wrote wavs/BluGre1214F_["6"]_295565095_295568223.wav
# go=True istart=295888679 iend=295894055 row_num=4311
# Wrote wavs/WhiWhi1541M_["5"]_295686918_295690606.wav
# go=True istart=295575233 iend=295578611 row_num=4299
# go=True istart=295711791 iend=295718260 row_num=4305
# Wrote wavs/BroGre1354M_["1"]_296677824_296742216.wav
# Wrote wavs/BluGre1214F_["5"]_295888679_295894055.wav
# go=True istart=296678656 iend=296685349 row_num=4319
# go=True istart=295913413 iend=295916595 row_num=4312
# Wrote wavs/BluGre1214F_["6"]_295575233_295578611.wav
# Wrote wavs/WhiWhi1541M_["3"]_295711791_295718260.wav
# go=True istart=296920762 iend=296926441 row_num=4327
# go=True istart=295750349 iend=295753595 row_num=4306
# Wrote wavs/WhiWhi1541M_["5"]_296678656_296685349.wav
# Wrote wavs/WhiWhi1541M_["5"]_295913413_295916595.wav
# Wrote wavs/WhiWhi1541M_["5"]_295750349_295753595.wav
# go=True istart=296723102 iend=296726132 row_num=4320
# go=True istart=295929875 iend=295935121 row_num=4313
# Wrote wavs/WhiWhi6607F_["6"]_296920762_296926441.wav
# go=True istart=295780428 iend=295783470 row_num=4307
# go=True istart=296938101 iend=296941813 row_num=4328
# go=True istart=297209619 iend=297215191 row_num=4336
# Wrote wavs/BluGre1214F_["6"]_296723102_296726132.wav
# Wrote wavs/BroGre1354M_["4"]_295929875_295935121.wav
# Wrote wavs/WhiWhi1541M_["5"]_295780428_295783470.wav
# go=True istart=295944476 iend=295947670 row_num=4314
# go=True istart=296729150 iend=296732420 row_num=4321
# Wrote wavs/BluGre1214F_["6"]_296938101_296941813.wav
# go=True istart=295785541 iend=295790400 row_num=4308
# go=True istart=297006436 iend=297009951 row_num=4329
# Wrote wavs/WhiWhi6607F_["6"]_297209619_297215191.wav
# Wrote wavs/BluGre1214F_["6"]_295944476_295947670.wav
# go=True istart=297262340 iend=297267134 row_num=4337
# Wrote wavs/BroGre1354M_["1"]_295785541_295790400.wav
# Wrote wavs/BluGre1214F_["6"]_296729150_296732420.wav
# Wrote wavs/BluGre1214F_["6"]_297006436_297009951.wav
# go=True istart=295954414 iend=295957586 row_num=4315
# Wrote wavs/BroGre1354M_["4"]_297262340_297267134.wav
# go=True istart=297040336 iend=297044679 row_num=4330
# go=True istart=297295825 iend=297299512 row_num=4338
# go=True istart=296735292 iend=296740340 row_num=4322
# Wrote wavs/WhiWhi1541M_["5"]_295954414_295957586.wav
# Wrote wavs/BluGre1214F_["6"]_297040336_297044679.wav
# go=True istart=295979507 iend=295982775 row_num=4316
# go=True istart=297105398 iend=297109435 row_num=4331
# Wrote wavs/BluGre1214F_["6"]_297295825_297299512.wav
# Wrote wavs/BluGre1214F_["6"]_296735292_296740340.wav
# go=True istart=297302736 iend=297305283 row_num=4339
# go=True istart=296741154 iend=296744486 row_num=4323
# Wrote wavs/WhiWhi1541M_["5"]_295979507_295982775.wav
# Wrote wavs/BluGre1214F_["6"]_297105398_297109435.wav
# go=True istart=296665749 iend=296672712 row_num=4317
# Wrote wavs/BluGre1214F_["6"]_296741154_296744486.wav
# go=True istart=297109421 iend=297115084 row_num=4332
# Wrote wavs/WhiWhi1541M_["5"]_297302736_297305283.wav
# go=True istart=296750141 iend=296753301 row_num=4324
# go=True istart=297324812 iend=297329004 row_num=4340
# Wrote wavs/BluGre1214F_["5"]_296665749_296672712.wav
# Wrote wavs/WhiWhi6607F_["6"]_297109421_297115084.wav
# go=True istart=297144643 iend=297149223 row_num=4333
# Wrote wavs/WhiWhi1541M_["5"]_296750141_296753301.wav
# Wrote wavs/BluGre1214F_["6"]_297324812_297329004.wav
# go=True istart=296754251 iend=296757202 row_num=4325
# go=True istart=297367001 iend=297371644 row_num=4341
# Wrote wavs/BluGre1214F_["6"]_297144643_297149223.wav
# go=True istart=297155314 iend=297158838 row_num=4334
# Wrote wavs/BluGre1214F_["5"]_296754251_296757202.wav
# Wrote wavs/BluGre1214F_["6"]_297367001_297371644.wav
# go=True istart=296767828 iend=296771201 row_num=4326
# go=True istart=298070022 iend=298074525 row_num=4342
# Wrote wavs/WhiWhi1541M_["6"]_297155314_297158838.wav
# Wrote wavs/BroGre1354M_["0"]_296767828_296771201.wav
# go=True istart=297207829 iend=297210849 row_num=4335
# Wrote wavs/BluGre1214F_["6"]_298070022_298074525.wav
# go=True istart=298089447 iend=298092579 row_num=4343
# Wrote wavs/WhiWhi1541M_["5"]_297207829_297210849.wav
# Wrote wavs/WhiWhi1541M_["5"]_298089447_298092579.wav

# %%
# Now that the H5 files are saved, we move on..
# except it isn't working.  I'm going to try to do it all in one loop

# %%
os.path.join(base_folder, 'h5filesAmp')
# Out:
# '/Users/williamwood/Documents/Data/Field Station Recordings/July_Recordings/14_38_03_18_07_2023_Maeves_data/h5filesAmp'
