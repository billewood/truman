# %%
# from scipy import integrate, optimize
from scipy.signal import chirp, spectrogram, find_peaks, windows, butter, sosfilt, sosfiltfilt, correlate
from scipy.io.wavfile import read, write
import IPython.display as ipd
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.colors as mcolors
import pickle
from soundsig.sound import BioSound 
from soundsig.sound import WavFile

from ipywidgets import interact, fixed
from ipywidgets import widgets
import matplotlib.pyplot as plt

def test_plot_spectrogram(title, w, fs):
    ff, tt, Sxx = spectrogram(w, fs=fs, nperseg=32, nfft=256)
    plt.pcolormesh(tt, ff[:145], Sxx[:145], cmap='gray_r', shading='gouraud')
    plt.title(title)
    plt.xlabel('t (sec)')
    plt.ylabel('Frequency (Hz)')
    plt.grid()

# %%
data_path = '/Users/williamwood/Documents/Sound_Localization/July_Recordings/audio_recordings/'
# data_file_1 = '/Users/williamwood/Documents/Sound Localization/audio_recordings/paired_recordings/second day/audio_458185000Hz_11-41-50_30-06-2023.wav'
# data_file_2 = '/Users/williamwood/Documents/Sound Localization/audio_recordings/paired_recordings/second day/audio_432735800Hz_11-41-51_30-06-2023.wav'
file_1_name = 'audio_442360000Hz_09-29-44_18-07-2023.wav'
file_2_name = 'audio_458185540Hz_09-29-42_18-07-2023.wav'
file_3_name = 'audio_423212900Hz_09-29-54_18-07-2023.wav'
file_4_name = 'audio_432736430Hz_09-29-58_18-07-2023.wav'

# %%
print(f'opening data file:{os.path.join(data_path, file_1_name)}')
print(f'saving as: {os.path.join(data_path, file_1_name[:-4] + "_1chan.wav")}')
# Out:
# opening data file:/Users/williamwood/Documents/Sound_Localization/July_Recordings/audio_recordings/audio_442360000Hz_09-29-44_18-07-2023.wav
# saving as: /Users/williamwood/Documents/Sound_Localization/July_Recordings/audio_recordings/audio_442360000Hz_09-29-44_18-07-2023_1chan.wav

# %%
# for resaving with only 1 channel or else biosound doesn't work
fs, data_wav = read(os.path.join(data_path, file_1_name))
print(f'opening data file:{os.path.join(data_path, file_1_name)}')
data_wav = data_wav[:,0] # just take the first channel, typically the second is empty

write(os.path.join(data_path, file_1_name[:-4] + '_1chan.wav'),fs,data_wav)
print(f'resaving with 1 channel as: {os.path.join(data_path, file_1_name[:-4] + "_1chan.wav")}')

print(f'length of file: {len(data_wav)/fs} s, fs={fs}, len in minutes:{(len(data_wav)/fs)/60}')

# lowpass_thresh = 18000
# highpass_thresh = 100
# order=10
# sos = butter(order, lowpass_thresh, 'lp', fs=fs, output='sos')
# print(f'lowpass_thresh: {lowpass_thresh}, highpass_thresh:{highpass_thresh}, order={order}')
# filtered = sosfiltfilt(sos, data_wav)
# Out:
# opening data file:/Users/williamwood/Documents/Sound_Localization/July_Recordings/audio_recordings/audio_442360000Hz_09-29-44_18-07-2023.wav
# resaving with 1 channel as: /Users/williamwood/Documents/Sound_Localization/July_Recordings/audio_recordings/audio_442360000Hz_09-29-44_18-07-2023_1chan.wav
# length of file: 3216.6830833333333 s, fs=48000, len in minutes:53.61138472222222

# %%
soundIn.
# Out:
# 2

# %%
filename = (file_1_name[:-4] + "_1chan.wav")

# Read the sound file
soundIn  = WavFile(file_name=os.path.join(data_path, filename)) 
filename, _ = os.path.splitext(filename)

# Here we parse the filename to get the birdname and the call type. 
# You will have to write custom code to extract your own identifiers.
birdname = filename[7:15]
calltype = filename[18:20]

# Create BioSound Object
myBioSound = BioSound(
    soundWave=soundIn.data.astype(float),
    fs=float(soundIn.sample_rate),
    emitter=birdname,
    calltype = calltype
  )
      
# Calculate the spectrogram and the rms
myBioSound.spectroCalc(
    spec_sample_rate=1000,
    freq_spacing=50,
    min_freq=0,
    max_freq=10000
)
myBioSound.rms = myBioSound.sound.std() 

# Calculate amplitude enveloppe
myBioSound.ampenv(cutoff_freq = 20, amp_sample_rate = 1000)

# Calculate the power spectrum
myBioSound.spectrum(f_high=10000)

# Calculate fundamental and related values.  These are the default values.
#   For the estimation of the fundamental, four methods are available: 
#   'AC' - Peak of the auto-correlation function
#   'ACA' - Peak of envelope of auto-correlation function 
#   'Cep' - First peak in cepstrum 
#   'Stack' - Fitting of harmonic stacks (default - works well for zebra finches)
myBioSound.fundest(
    maxFund = 1500,
    minFund = 300,
    lowFc = 200,
    highFc = 6000, 
    minSaliency = 0.5,
    debugFig = 0, 
    minFormantFreq = 500,
    maxFormantBW = 500,
    windowFormant = 0.1,
    method="Stack"
  )

# Calculate the MPS
myBioSound.mpsCalc(window=0.1, Norm = True)

# Plot the result
myBioSound.plot(DBNOISE=50, f_low=250, f_high=10000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 21
#      13 myBioSound = BioSound(
#      14     soundWave=soundIn.data.astype(float),
#      15     fs=float(soundIn.sample_rate),
#      16     emitter=birdname,
#      17     calltype = calltype
#      18   )
#      20 # Calculate the spectrogram and the rms
# ---> 21 myBioSound.spectroCalc(
#      22     spec_sample_rate=1000,
#      23     freq_spacing=50,
#      24     min_freq=0,
#      25     max_freq=10000
#      26 )
#      27 myBioSound.rms = myBioSound.sound.std()
#      29 # Calculate amplitude enveloppe
#
# File /opt/miniconda3/lib/python3.9/site-packages/soundsig/sound.py:285, in BioSound.spectroCalc(self, spec_sample_rate, freq_spacing, min_freq, max_freq)
#     283 self.to = t
#     284 self.fo = f
# --> 285 self.spectro = 20*np.log10(np.abs(spec))
#
# KeyboardInterrupt:

# %%
start_time = 2806
len_time = 4


plt.plot(filtered[round(start_time*fs):round((start_time+len_time)*fs)])
plt.figure()
x = filtered[round(start_time*fs):round((start_time+len_time)*fs)]
f, t, Sxx = spectrogram(x, fs, nfft=1028)
plt.pcolormesh(t, f[0:300], Sxx[0:300],shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
fs, data_wav_1 = read(data_file_1)
fs2, data_wav_2 = read(data_file_2)

sos = butter(2, lowpass_thresh, 'lp', fs=fs, output='sos')
filtered_1 = sosfiltfilt(sos, data_wav_1)
filtered_2 = sosfiltfilt(sos, data_wav_2)

# fs, data_wav_1 = read(data_file_1)
# fs2, data_wav_2 = read(data_file_2)

sos = butter(2, highpass_thresh, 'hp', fs=fs, output='sos')
filtered_1 = sosfiltfilt(sos, data_wav_1)
filtered_2 = sosfiltfilt(sos, data_wav_2)

# %% [markdown]
# # aligning by cross_correlating is not working, they are too different and the artifacts are too big

# %%
start = 10
stop = 30
chunk_1 = filtered_1[fs*start:fs*stop]
chunk_2 = filtered_2[fs*start:fs*stop]
lag=np.argmax(correlate(chunk_1,chunk_2))
print(lag)
# Out:
# 1011160

# %%
# aligning by cross_correlating is not working
plt.plot(chunk_1)
plt.plot(chunk_2)
plt.vlines(lag,min(min(chunk_1),min(chunk_2)), max(chunk_1))

# %% [markdown]
# ## so let's move on and subtract the artifacts.

# %%
wav_1_std = np.std(filtered_1)
wav_1_mean = np.mean(filtered_1)
wav_2_std = np.std(filtered_2)
wav_2_mean = np.mean(filtered_2)

# %%
print(f'mean 1 and 2: {wav_1_mean, wav_2_mean}, std 1 and 2: {wav_1_std, wav_2_std}')
# Out:
# mean 1 and 2: (-0.2093643038236215, 0.2216323156987788), std 1 and 2: (3309662.3212444396, 4482002.755931827)

# %% [markdown]
# ## manually fix this stupid discontinuity in DC offset

# %%
# adjust_time = round(50.226*fs)
# plt.plot(filtered_1[adjust_time-5000:adjust_time+5000],'.')
# filtered_1[:adjust_time] -= np.mean(filtered_1[0:adjust_time])
# plt.plot(filtered_1[adjust_time-5000:adjust_time+5000],'c.')

# %%
plt.plot(filtered_1[0:fs*10])

# %%
plt.plot(data_wav_1[0fs*5])
# Out:
#   Cell In[82], line 1
#     plt.plot(data_wav_1[0fs*5])
#                          ^
# SyntaxError: invalid syntax
